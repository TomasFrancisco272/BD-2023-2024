# %% [markdown]
# # Conecções

# %%
import time
import oracledb
from pymongo import MongoClient
import psutil
from neo4j import GraphDatabase

def connect_to_oracle():
    try:
        connection = oracledb.connect (
            user = "USER_WorkBD_hospital",
            password = "hospital24",
            dsn = "localhost:1521/xe"
        )
        print("Conexão bem sucedida ao OracleDB!")
        return connection
    except Exception:
        print("Erro ao conectar ao Oracle")
        return None
    
def connect_to_mongo():
    try: 
        # Conectar-se ao MongoDB
        client = MongoClient('localhost', 27017)
        # Acessar o banco de dados e a coleção
        db = client['HospitalDatabase']
        collection = db['HospitalCollection']
                
        print("Conexão bem sucedida ao MongoDB!")
        return collection
    
    except Exception:
        print("Erro ao conectar ao MongoDB")
        return

def connect_to_neo4j():
    try:
        uri = "bolt://localhost:7687"
        user = "neo4j"
        password = "abcd1234"
        driver = GraphDatabase.driver(uri, auth=(user, password))
        print("Conexão bem sucedida ao Neo4j!")
        return driver
    except Exception:
        print("Erro ao conectar ao Neo4j")
        return

# Conectar ao Oracle
oracle_connection = connect_to_oracle()

# Conectar ao MongoDB
mongo_collection = connect_to_mongo()

# Conectar ao Neo4j
neo4j_connection = connect_to_neo4j()

def monitor_usage():
    process = psutil.Process()
    cpu_usage = process.cpu_percent(interval=1)
    memory_usage = process.memory_info().rss
    return cpu_usage, memory_usage

def execute_query(query):
    with neo4j_connection.session() as session:
        result = session.run(query)
        return result

def print_results(num):
    print("Query " + num + "\n")
    print("Oracle:")
    print(queries[num]["oracleOutput"])
    print("Mongo:")
    print(queries[num]["mongoOutput"])
    print("Neo4j:")
    print(queries[num]["neo4jOutput"])
    print()
    print("Tempo de execução:")
    print("- Oracle:", queries[num]["oracleTime"])
    print("- Mongo:", queries[num]["mongoTime"])
    print("- Neo4j:",queries[num]["neo4jTime"])
    print("Utilização de cpu:")
    print("- Oracle:", queries[num]["oracleCPU"])
    print("- Mongo:", queries[num]["mongoCPU"])
    print("- Neo4j:",queries[num]["neo4jCPU"])
    print("Utilização de memória:")
    print("- Oracle:", queries[num]["oracleMEM"])
    print("- Mongo:", queries[num]["mongoMEM"])
    print("- Neo4j:",queries[num]["neo4jMEM"])

queries = {}
# Out:
# Conexão bem sucedida ao OracleDB!
# Conexão bem sucedida ao MongoDB!
# Conexão bem sucedida ao Neo4j!

# %% [markdown]
# ## Query 1
# **Selecionar todas as informações de todos os membros do Staff (doctors, nurses, technicians).**

# %%
num = "1"
queries[num] = {
    "Query": "Selecionar todas as informações de todos os membros do Staff (doctors, nurses, technicians).",
    "oracleTime": -1,
    "oracleOutput": "",
    "oracleCPU": -1,
    "oracleMEM": -1,
    "mongoTime": -1,
    "mongoOutput": "",
    "mongoCPU": -1,
    "mongoMEM": -1,
    "neo4jTime": -1,
    "neo4jOutput": "",
    "neo4jCPU": -1,
    "neo4jMEM": -1
}

# oracle
cpu_before, mem_before = monitor_usage()
start = time.time()
cursor = oracle_connection.cursor()
cursor.execute("SELECT * FROM Staff")
result = cursor.fetchall()
end = time.time()
cpu_after, mem_after = monitor_usage()
queries[num]["oracleTime"] = f"{end - start:.10f}"
queries[num]["oracleOutput"] = result
queries[num]["oracleCPU"] = cpu_after - cpu_before
queries[num]["oracleMEM"] = mem_after - mem_before

# mongo
cpu_before, mem_before = monitor_usage()
start = time.time()
result = mongo_collection.find(
    {},
    {
        "_id": 0,
        "Doctors": "$EPISODE.APPOINTMENT.DOCTOR",
        "Nurses": "$EPISODE.HOSPITALIZATION.NURSE",
        "Technicians": "$EPISODE.LAB_SCREENING.TECHNICIAN"
    }
)
end = time.time()
cpu_after, mem_after = monitor_usage()
queries[num]["mongoTime"] = f"{end - start:.10f}"
queries[num]["mongoOutput"] = list(result)
queries[num]["mongoCPU"] = cpu_after - cpu_before
queries[num]["mongoMEM"] = mem_after - mem_before

# neo4j
cpu_before, mem_before = monitor_usage()
start = time.time()
cypher_query = """
MATCH (s:Staff)
RETURN s
"""
result = execute_query(cypher_query)
end = time.time()
cpu_after, mem_after = monitor_usage()

queries[num]["neo4jTime"] = f"{end - start:.10f}"
queries[num]["neo4jOutput"] = result
queries[num]["neo4jCPU"] = cpu_after - cpu_before
queries[num]["neo4jMEM"] = mem_after - mem_before

# Imprimir os resultados da query 1
print_results(num)
# Out:
# Query 1
#
# Oracle:
# [(1, 'Jillian', 'Gordon', datetime.datetime(2018, 8, 25, 0, 0), None, 'juan14@example.net', '"435 Dylan Neck Suite 993', 329594711, 25, 'Y'), (2, 'James', 'Williams', datetime.datetime(2018, 4, 10, 0, 0), datetime.datetime(2023, 1, 5, 0, 0), 'henryjennifer@example.net', 'Kleinhaven, CT 37220"', 527613638, 16, 'N'), (3, 'Joshua', 'Carter', datetime.datetime(2018, 3, 15, 0, 0), None, 'michael82@example.org', '"Unit 4429 Box 5356', 724148400, 27, 'Y'), (4, 'Joe', 'Ferguson', datetime.datetime(2018, 8, 10, 0, 0), None, 'vsullivan@example.org', 'DPO AE 27029"', 531094042, 17, 'Y'), (5, 'Travis', 'Ramos', datetime.datetime(2019, 10, 15, 0, 0), None, 'leah21@example.org', '"12795 Solis Landing Apt. 269', 857991076, 21, 'Y'), (6, 'Lisa', 'Hayes', datetime.datetime(2023, 5, 10, 0, 0), None, 'mprice@example.com', 'Trevorfurt, IN 02637"', 685569160, 1, 'Y'), (7, 'Dawn', 'Hopkins', datetime.datetime(2019, 11, 28, 0, 0), datetime.datetime(2022, 1, 5, 0, 0), 'jenkinsheather@example.com', '"02444 Anderson Street Suite 139', 215259434, 16, 'N'), (8, 'Dawn', 'Roberts', datetime.datetime(2019, 12, 1, 0, 0), None, 'laurie35@example.net', 'Leeville, SD 39088"', 391666874, 14, 'Y'), (9, 'Jessica', 'Jones', datetime.datetime(2019, 1, 5, 0, 0), None, 'larrykrause@example.net', '"548 Bonilla Extensions', 410402409, 26, 'Y'), (10, 'Rachel', 'Wilson', datetime.datetime(2019, 7, 10, 0, 0), datetime.datetime(2022, 1, 5, 0, 0), 'jenna85@example.org', 'West Robertshire, MH 77607"', 745100367, 20, 'N'), (11, 'Kimberly', 'Blankenship', datetime.datetime(2019, 1, 5, 0, 0), None, 'melissa35@example.org', '"641 Tyler Fork Suite 201', 281673265, 26, 'Y'), (12, 'Keith', 'Simmons', datetime.datetime(2018, 12, 1, 0, 0), None, 'tylerthompson@example.org', 'Browntown, WY 84829"', 899470207, 14, 'Y'), (13, 'William', 'Grant', datetime.datetime(2019, 7, 10, 0, 0), datetime.datetime(2022, 1, 5, 0, 0), 'seanlyons@example.org', '"41829 Andrew Course Apt. 567', 804408507, 20, 'N'), (14, 'Andrew', 'Deleon', datetime.datetime(2018, 9, 15, 0, 0), None, 'dominiquemcdaniel@example.com', 'North Kayla, ME 24616"', 184426607, 27, 'Y'), (15, 'Emily', 'Rowe', datetime.datetime(2018, 4, 10, 0, 0), datetime.datetime(2023, 1, 5, 0, 0), 'thompsonsuzanne@example.org', '"2191 Little Fall Apt. 951', 457794054, 16, 'N'), (16, 'Kenneth', 'Ayers', datetime.datetime(2018, 8, 25, 0, 0), None, 'emily66@example.net', 'New Sarahberg, IA 31150"', 719506165, 25, 'Y'), (17, 'Daniel', 'Mills', datetime.datetime(2018, 8, 10, 0, 0), None, 'lthompson@example.org', '"389 Jeffrey Mountain', 481584738, 17, 'Y'), (18, 'Tina', 'Gilbert', datetime.datetime(2019, 10, 15, 0, 0), None, 'danjones@example.net', 'Lindaview, MA 29212"', 522524152, 21, 'Y'), (19, 'Scott', 'Holmes', datetime.datetime(2023, 5, 10, 0, 0), None, 'tammy41@example.net', '"107 Velasquez Corner', 105899430, 1, 'Y'), (20, 'Jennifer', 'Ball', datetime.datetime(2019, 11, 28, 0, 0), datetime.datetime(2022, 1, 5, 0, 0), 'brandymartinez@example.com', 'Lake Tina, IA 30662"', 404767927, 16, 'N'), (21, 'Stacy', 'Logan', datetime.datetime(2019, 12, 1, 0, 0), None, 'uturner@example.net', '"771 Jennifer Bypass', 633814140, 14, 'Y'), (22, 'Jeffrey', 'Jones', datetime.datetime(2019, 1, 5, 0, 0), None, 'uscott@example.com', 'Candicefurt, AS 18171"', 258505600, 26, 'Y'), (23, 'Cheryl', 'Christensen', datetime.datetime(2018, 12, 1, 0, 0), None, 'morganstephen@example.com', '"219 Tammy Meadows', 260911313, 14, 'Y'), (24, 'James', 'Carpenter', datetime.datetime(2019, 7, 10, 0, 0), datetime.datetime(2022, 1, 5, 0, 0), 'christineguzman@example.com', 'West Brianshire, NE 37671"', 124291244, 20, 'N'), (25, 'Matthew', 'Espinoza', datetime.datetime(2018, 9, 15, 0, 0), None, 'roger32@example.net', '"1163 Ethan Underpass Apt. 901', 402431746, 27, 'Y'), (26, 'Vickie', 'Gonzalez', datetime.datetime(2018, 4, 10, 0, 0), datetime.datetime(2023, 1, 5, 0, 0), 'lolson@example.com', 'East Michael, CT 20442"', 925078857, 16, 'N'), (27, 'Denise', 'Acosta', datetime.datetime(2018, ...
# Mongo:
# [{'Doctors': [[[{'QUALIFICATIONS': 'PhD', 'EMP_ID': 99, 'EMP_FNAME': 'Brittany', 'EMP_LNAME': 'Collins', 'DATE_JOINING': '2013-10-02', 'DATE_SEPERATION': None, 'EMAIL': 'jennifer69@example.net', 'ADDRESS': '"6791 Riggs Avenue Suite 321', 'SSN': 531214210, 'IS_ACTIVE_STATUS': 'Y', 'DEPARTMENT': [{'IDDEPARTMENT': 5, 'DEPT_HEAD': 'Christopher Lee', 'DEPT_NAME': 'Emergency_1', 'EMP_COUNT': 2}]}]], [], [[{'QUALIFICATIONS': 'MD', 'EMP_ID': 96, 'EMP_FNAME': 'Robert', 'EMP_LNAME': 'Perez', 'DATE_JOINING': '2013-10-02', 'DATE_SEPERATION': None, 'EMAIL': 'wagnersarah@example.net', 'ADDRESS': 'South Danielmouth, TN 48233"', 'SSN': 433087970, 'IS_ACTIVE_STATUS': 'Y', 'DEPARTMENT': [{'IDDEPARTMENT': 2, 'DEPT_HEAD': 'Michael Williams', 'DEPT_NAME': 'Emergency_2', 'EMP_COUNT': 3}]}]]], 'Nurses': [[], [[{'EMP_ID': 95, 'EMP_FNAME': 'Kimberly', 'EMP_LNAME': 'Hernandez', 'DATE_JOINING': '2013-10-02', 'DATE_SEPERATION': None, 'EMAIL': 'kingjacob@example.com', 'ADDRESS': '"006 Daugherty Forest', 'SSN': 562577558, 'IS_ACTIVE_STATUS': 'Y', 'DEPARTMENT': [{'IDDEPARTMENT': 1, 'DEPT_HEAD': 'John Smith', 'DEPT_NAME': 'Cardiology_1', 'EMP_COUNT': 2}]}]], []], 'Technicians': [[[{'EMP_ID': 70, 'EMP_FNAME': 'Deborah', 'EMP_LNAME': 'Collins', 'DATE_JOINING': '2014-10-02', 'DATE_SEPERATION': '2018-10-02', 'EMAIL': 'julie57@example.org', 'ADDRESS': 'Freemanshire, FM 38384"', 'SSN': 187814750, 'IS_ACTIVE_STATUS': 'N', 'DEPARTMENT': [{'IDDEPARTMENT': 3, 'DEPT_HEAD': 'Emily Johnson', 'DEPT_NAME': 'Diagnostic_3', 'EMP_COUNT': 3}]}]], [[{'EMP_ID': 73, 'EMP_FNAME': 'Linda', 'EMP_LNAME': 'White', 'DATE_JOINING': '2014-10-02', 'DATE_SEPERATION': '2018-10-02', 'EMAIL': 'janicedunn@example.net', 'ADDRESS': '"2256 Robert Trail Suite 219', 'SSN': 132945328, 'IS_ACTIVE_STATUS': 'N', 'DEPARTMENT': [{'IDDEPARTMENT': 6, 'DEPT_HEAD': 'Matthew Martinez', 'DEPT_NAME': 'Diagnostic_1', 'EMP_COUNT': 1}]}]], []]}, {'Doctors': [[], [], []], 'Nurses': [[[{'EMP_ID': 4, 'EMP_FNAME': 'Joe', 'EMP_LNAME': 'Ferguson', 'DATE_JOINING': '2018-08-10', 'DATE_SEPERATION': None, 'EMAIL': 'vsullivan@example.org', 'ADDRESS': 'DPO AE 27029"', 'SSN': 531094042, 'IS_ACTIVE_STATUS': 'Y', 'DEPARTMENT': [{'IDDEPARTMENT': 17, 'DEPT_HEAD': 'Ethan Brown', 'DEPT_NAME': 'Gynecology', 'EMP_COUNT': 5}]}]], [[{'EMP_ID': 20, 'EMP_FNAME': 'Jennifer', 'EMP_LNAME': 'Ball', 'DATE_JOINING': '2019-11-28', 'DATE_SEPERATION': '2022-01-05', 'EMAIL': 'brandymartinez@example.com', 'ADDRESS': 'Lake Tina, IA 30662"', 'SSN': 404767927, 'IS_ACTIVE_STATUS': 'N', 'DEPARTMENT': [{'IDDEPARTMENT': 16, 'DEPT_HEAD': 'Sophia Lopez', 'DEPT_NAME': 'Ophthalmology', 'EMP_COUNT': 5}]}]], [[{'EMP_ID': 26, 'EMP_FNAME': 'Vickie', 'EMP_LNAME': 'Gonzalez', 'DATE_JOINING': '2018-04-10', 'DATE_SEPERATION': '2023-01-05', 'EMAIL': 'lolson@example.com', 'ADDRESS': 'East Michael, CT 20442"', 'SSN': 925078857, 'IS_ACTIVE_STATUS': 'N', 'DEPARTMENT': [{'IDDEPARTMENT': 16, 'DEPT_HEAD': 'Sophia Lopez', 'DEPT_NAME': 'Ophthalmology', 'EMP_COUNT': 5}]}]]], 'Technicians': [[[{'EMP_ID': 49, 'EMP_FNAME': 'Ashley', 'EMP_LNAME': 'Stein', 'DATE_JOINING': '2014-10-02', 'DATE_SEPERATION': None, 'EMAIL': 'krystal59@example.org', 'ADDRESS': '"8049 Adrian Throughway', 'SSN': 414092098, 'IS_ACTIVE_STATUS': 'Y', 'DEPARTMENT': [{'IDDEPARTMENT': 9, 'DEPT_HEAD': 'Travis Smith', 'DEPT_NAME': 'Diagnostic_2', 'EMP_COUNT': 3}]}]], [[{'EMP_ID': 76, 'EMP_FNAME': 'Robert', 'EMP_LNAME': 'Day', 'DATE_JOINING': '2014-10-02', 'DATE_SEPERATION': None, 'EMAIL': 'perkinsmaria@example.org', 'ADDRESS': 'Aprilmouth, OH 09009"', 'SSN': 429282057, 'IS_ACTIVE_STATUS': 'Y', 'DEPARTMENT': [{'IDDEPARTMENT': 9, 'DEPT_HEAD': 'Travis Smith', 'DEPT_NAME': 'Diagnostic_2', 'EMP_COUNT': 3}]}]], []]}, {'Doctors': [[], [], []], 'Nurses': [[[{'EMP_ID': 5, 'EMP_FNAME': 'Travis', 'EMP_LNAME': 'Ramos', 'DATE_JOINING': '2019-10-15', 'DATE_SEPERATION': None, 'EMAIL': 'leah21@example.org', 'ADDRESS': '"12795 Solis Landing Apt. 269', 'SSN': 857991076, 'IS_ACTIVE_STATUS': 'Y', 'DEPARTMENT': [{'IDDEPARTMENT': 21, 'DE ...
# Neo4j:
# <neo4j._sync.work.result.Result object at 0x10c788310>
#
# Tempo de execução:
# - Oracle: 0.0050051212
# - Mongo: 0.0001618862
# - Neo4j: 0.0335609913
# Utilização de cpu:
# - Oracle: -0.2
# - Mongo: 0.0
# - Neo4j: 0.1
# Utilização de memória:
# - Oracle: 188416
# - Mongo: 0
# - Neo4j: 495616

# %% [markdown]
# ## Query 2
# **Selecionar todos os patients onde o blood_type é 'A+'**

# %%
num = "2"
queries[num] = {
    "Query": "Selecionar todos os patients onde o blood_type é 'A+'",
    "oracleTime": -1,
    "oracleOutput": "",
    "oracleCPU": -1,
    "oracleMEM": -1,
    "mongoTime": -1,
    "mongoOutput": "",
    "mongoCPU": -1,
    "mongoMEM": -1,
    "neo4jTime": -1,
    "neo4jOutput": "",
    "neo4jCPU": -1,
    "neo4jMEM": -1
}

# Executar a query 2
# oracle
cpu_before, mem_before = monitor_usage()
start = time.time()
cursor = oracle_connection.cursor()
cursor.execute("SELECT * FROM patient WHERE blood_type = 'A+'")
result = cursor.fetchall()
end = time.time()
cpu_after, mem_after = monitor_usage()
queries[num]["oracleTime"] = f"{end - start:.10f}"
queries[num]["oracleOutput"] = result
queries[num]["oracleCPU"] = cpu_after - cpu_before
queries[num]["oracleMEM"] = mem_after - mem_before

# mongo
cpu_before, mem_before = monitor_usage()
start = time.time()
result = mongo_collection.find({ "BLOOD_TYPE": "A+" })
end = time.time()
cpu_after, mem_after = monitor_usage()
queries[num]["mongoTime"] = f"{end - start:.10f}"
queries[num]["mongoOutput"] = list(result)
queries[num]["mongoCPU"] = cpu_after - cpu_before
queries[num]["mongoMEM"] = mem_after - mem_before

# neo4j
cpu_before, mem_before = monitor_usage()
start = time.time()
cypher_query = """
MATCH (p:Patient {blood_type: 'A+'})
RETURN p
"""
result = execute_query(cypher_query)
end = time.time()

queries[num]["neo4jTime"] = f"{end - start:.10f}"
queries[num]["neo4jOutput"] = result
queries[num]["neo4jCPU"] = cpu_after - cpu_before
queries[num]["neo4jMEM"] = mem_after - mem_before
cpu_after, mem_after = monitor_usage()

# Imprimir os resultados da query 2
print_results(num)
# Out:
# Query 2
#
# Oracle:
# [(1, 'John', 'Doe', 'A+', '123-456-7890', 'john.doe@example.com', 'Male', 'POL001', datetime.datetime(1985, 7, 15, 0, 0)), (10, 'Emma', 'Perez', 'A+', '345-678-9012', 'emma.perez@example.com', 'Female', 'POL010', datetime.datetime(1992, 1, 5, 0, 0)), (18, 'Sophia', 'Gonzalez', 'A+', '666-777-8888', 'sophia.gonzalez@example.com', 'Female', 'POL008', datetime.datetime(1988, 11, 25, 0, 0)), (25, 'William', 'Nguyen', 'A+', '567-890-1234', 'william.nguyen@example.com', 'Male', 'POL005', datetime.datetime(1990, 12, 2, 0, 0)), (32, 'Isabella', 'Phan', 'A+', '234-567-8901', 'isabella.phan@example.com', 'Female', 'POL002', datetime.datetime(1995, 9, 13, 0, 0)), (40, 'Alexander', 'Ho', 'A+', '012-345-6789', 'alexander.ho@example.com', 'Male', 'POL002', datetime.datetime(1988, 8, 25, 0, 0)), (46, 'Daniel', 'Do', 'A+', '678-901-2345', 'daniel.do@example.com', 'Male', 'POL006', datetime.datetime(1983, 8, 7, 0, 0)), (54, 'Noah', 'Vo', 'A+', '450-987-6543', 'noah.vo@example.com', 'Male', 'POL004', datetime.datetime(1983, 12, 5, 0, 0)), (68, 'Alexander', 'Dang', 'A+', '876-543-2109', 'alexander.dang@example.com', 'Male', 'POL008', datetime.datetime(1988, 12, 25, 0, 0)), (76, 'William', 'Bui', 'A+', '432-109-8765', 'william.bui@example.com', 'Male', 'POL006', datetime.datetime(1994, 7, 15, 0, 0)), (87, 'Madison', 'Nguyen', 'A+', '321-098-7654', 'madison.nguyen@example.com', 'Female', 'POL007', datetime.datetime(1984, 12, 20, 0, 0))]
# Mongo:
# [{'_id': ObjectId('6658a37c136de9ad2109117c'), 'IDPATIENT': 1, 'PATIENT_FNAME': 'John', 'PATIENT_LNAME': 'Doe', 'BLOOD_TYPE': 'A+', 'PHONE': '123-456-7890', 'EMAIL': 'john.doe@example.com', 'GENDER': 'Male', 'POLICY_NUMBER': 'POL001', 'BIRTHDAY': '1985-07-15', 'HISTORY': [{'RECORD_ID': 1, 'CONDITION': 'Flu', 'RECORD_DATE': '2023-01-15'}, {'RECORD_ID': 19, 'CONDITION': 'Gastritis', 'RECORD_DATE': '2024-07-15'}, {'RECORD_ID': 21, 'CONDITION': 'Gastritis', 'RECORD_DATE': '2024-07-15'}, {'RECORD_ID': 26, 'CONDITION': 'Rheumatoid Arthritis', 'RECORD_DATE': '2023-12-10'}], 'INSURANCE': [{'POLICY_NUMBER': 'POL001', 'PROVIDER': 'ABC Insurance', 'INSURANCE_PLAN': 'Standard Plan', 'CO_PAY': 50.0, 'COVERAGE': 'Full Coverage', 'MATERNITY': 'Y', 'DENTAL': 'N', 'OPTICAL': 'Y'}], 'EMERGENCY_CONTACT': [{'CONTACT_NAME': 'Emma Thompson', 'PHONE': '111-222-3323', 'RELATION': 'Sibling'}, {'CONTACT_NAME': 'John Doe', 'PHONE': '111-222-3333', 'RELATION': 'Father'}], 'EPISODE': [{'IDEPISODE': 1, 'BILL': [], 'PRESCRIPTION': [{'IDPRESCRIPTION': 541, 'PRESCRIPTION_DATE': '2013-12-21', 'DOSAGE': 72, 'MEDICINE': [{'IDMEDICINE': 1, 'M_NAME': 'Paracetamol', 'M_QUANTITY': 50, 'M_COST': 10.0}]}, {'IDPRESCRIPTION': 542, 'PRESCRIPTION_DATE': '2013-12-21', 'DOSAGE': 47, 'MEDICINE': [{'IDMEDICINE': 2, 'M_NAME': 'Ibuprofen', 'M_QUANTITY': 30, 'M_COST': 15.0}]}, {'IDPRESCRIPTION': 543, 'PRESCRIPTION_DATE': '2013-12-21', 'DOSAGE': 64, 'MEDICINE': [{'IDMEDICINE': 3, 'M_NAME': 'Amoxicillin', 'M_QUANTITY': 20, 'M_COST': 20.0}]}, {'IDPRESCRIPTION': 544, 'PRESCRIPTION_DATE': '2013-12-21', 'DOSAGE': 9, 'MEDICINE': [{'IDMEDICINE': 4, 'M_NAME': 'Ciprofloxacin', 'M_QUANTITY': 25, 'M_COST': 25.0}]}, {'IDPRESCRIPTION': 545, 'PRESCRIPTION_DATE': '2013-12-21', 'DOSAGE': 90, 'MEDICINE': [{'IDMEDICINE': 5, 'M_NAME': 'Lisinopril', 'M_QUANTITY': 40, 'M_COST': 30.0}]}], 'HOSPITALIZATION': [], 'APPOINTMENT': [{'SCHEDULED_ON': '2013-11-20', 'APPOINTMENT_DATE': '2013-12-21', 'APPOINTMENT_TIME': '13:13', 'DOCTOR': [{'QUALIFICATIONS': 'PhD', 'EMP_ID': 99, 'EMP_FNAME': 'Brittany', 'EMP_LNAME': 'Collins', 'DATE_JOINING': '2013-10-02', 'DATE_SEPERATION': None, 'EMAIL': 'jennifer69@example.net', 'ADDRESS': '"6791 Riggs Avenue Suite 321', 'SSN': 531214210, 'IS_ACTIVE_STATUS': 'Y', 'DEPARTMENT': [{'IDDEPARTMENT': 5, 'DEPT_HEAD': 'Christopher Lee', 'DEPT_NAME': 'Emergency_1', 'EMP_COUNT': 2}]}]}], 'LAB_SCREENING': [{'LAB_ID': 99, 'TEST_COST': 57.68, 'TEST_DATE': '2013-12-21', 'TECHNICIAN': [{'EMP_ID': 70, 'EMP_FNAME': 'Deborah', 'EMP_LNAME': 'Collins', 'DATE_JOINING': '2014-10-02', 'DATE_SEPERATION': '2018-10-02', 'EMAIL': 'julie57@example.org', 'ADDRESS': 'Freemanshire, FM 38384"', 'SSN': 187814750, 'IS_ACTIVE_STATUS': 'N', 'DEPARTMENT': [{'IDDEPARTMENT': 3, 'DEPT_HEAD': 'Emily Johnson', 'DEPT_NAME': 'Diagnostic_3', 'EMP_COUNT': 3}]}]}]}, {'IDEPISODE': 165, 'BILL': [], 'PRESCRIPTION': [{'IDPRESCRIPTION': 106, 'PRESCRIPTION_DATE': '2019-05-06', 'DOSAGE': 39, 'MEDICINE': [{'IDMEDICINE': 1, 'M_NAME': 'Paracetamol', 'M_QUANTITY': 50, 'M_COST': 10.0}]}, {'IDPRESCRIPTION': 107, 'PRESCRIPTION_DATE': '2019-05-06', 'DOSAGE': 22, 'MEDICINE': [{'IDMEDICINE': 2, 'M_NAME': 'Ibuprofen', 'M_QUANTITY': 30, 'M_COST': 15.0}]}, {'IDPRESCRIPTION': 108, 'PRESCRIPTION_DATE': '2019-05-06', 'DOSAGE': 95, 'MEDICINE': [{'IDMEDICINE': 3, 'M_NAME': 'Amoxicillin', 'M_QUANTITY': 20, 'M_COST': 20.0}]}, {'IDPRESCRIPTION': 109, 'PRESCRIPTION_DATE': '2019-05-06', 'DOSAGE': 50, 'MEDICINE': [{'IDMEDICINE': 4, 'M_NAME': 'Ciprofloxacin', 'M_QUANTITY': 25, 'M_COST': 25.0}]}, {'IDPRESCRIPTION': 110, 'PRESCRIPTION_DATE': '2019-05-06', 'DOSAGE': 61, 'MEDICINE': [{'IDMEDICINE': 5, 'M_NAME': 'Lisinopril', 'M_QUANTITY': 40, 'M_COST': 30.0}]}, {'IDPRESCRIPTION': 111, 'PRESCRIPTION_DATE': '2019-05-06', 'DOSAGE': 49, 'MEDICINE': [{'IDMEDICINE': 6, 'M_NAME': 'Atorvastatin', 'M_QUANTITY': 35, 'M_COST': 20.0}]}, {'IDPRESCRIPTION': 112, 'PRESCRIPTION_DATE': '2019-05-06', 'DOSAGE': 15, 'MEDICINE': [{'IDMEDICINE': 7, 'M_NAME': 'Metformin', 'M_QUA ...
# Neo4j:
# <neo4j._sync.work.result.Result object at 0x119245f10>
#
# Tempo de execução:
# - Oracle: 0.0089859962
# - Mongo: 0.0001583099
# - Neo4j: 0.1698651314
# Utilização de cpu:
# - Oracle: -0.3
# - Mongo: 0.2
# - Neo4j: 0.2
# Utilização de memória:
# - Oracle: -13758464
# - Mongo: -21368832
# - Neo4j: -425984

# %% [markdown]
# ## Query 3
# **Buscar as informações do paciente de id 10.**

# %%
num = "3"
queries[num] = {
    "Query": "Buscar as informações do paciente de id 10.",
    "oracleTime": -1,
    "oracleOutput": "",
    "oracleCPU": -1,
    "oracleMEM": -1,
    "mongoTime": -1,
    "mongoOutput": "",
    "mongoCPU": -1,
    "mongoMEM": -1,
    "neo4jTime": -1,
    "neo4jOutput": "",
    "neo4jCPU": -1,
    "neo4jMEM": -1
}

# Executar a query 3
# oracle
cpu_before, mem_before = monitor_usage()
start = time.time()
cursor = oracle_connection.cursor()
cursor.execute("SELECT * FROM patient WHERE idpatient = 10")
result = cursor.fetchall()
end = time.time()
cpu_after, mem_after = monitor_usage()
queries[num]["oracleTime"] = f"{end - start:.10f}"
queries[num]["oracleOutput"] = result
queries[num]["oracleCPU"] = cpu_after - cpu_before
queries[num]["oracleMEM"] = mem_after - mem_before

# mongo
cpu_before, mem_before = monitor_usage()
start = time.time()
result = mongo_collection.find(
    { "IDPATIENT": 10 }, {
        "_id": 0,
        "IDPATIENT": 1,
        "PATIENT_FNAME": 1,
        "PATIENT_LNAME": 1,
        "BLOOD_TYPE": 1,
        "PHONE": 1,
        "EMAIL": 1,
        "GENDER": 1,
        "POLICY_NUMBER": 1,
        "BIRTHDAY": 1
        }
    )
end = time.time()
cpu_after, mem_after = monitor_usage()
queries[num]["mongoTime"] = f"{end - start:.10f}"
queries[num]["mongoOutput"] = list(result)
queries[num]["mongoCPU"] = cpu_after - cpu_before
queries[num]["mongoMEM"] = mem_after - mem_before

# neo4j
cpu_before, mem_before = monitor_usage()
start = time.time()
cypher_query = """
MATCH (p:Patient)
WHERE p.idpatient = 10
RETURN p
"""
result = execute_query(cypher_query)
end = time.time()
cpu_after, mem_after = monitor_usage()

queries[num]["neo4jTime"] = f"{end - start:.10f}"
queries[num]["neo4jOutput"] = result
queries[num]["neo4jCPU"] = cpu_after - cpu_before
queries[num]["neo4jMEM"] = mem_after - mem_before

# Imprimir os resultados da query 3
print_results(num)
# Out:
# Query 3
#
# Oracle:
# [(10, 'Emma', 'Perez', 'A+', '345-678-9012', 'emma.perez@example.com', 'Female', 'POL010', datetime.datetime(1992, 1, 5, 0, 0))]
# Mongo:
# [{'IDPATIENT': 10, 'PATIENT_FNAME': 'Emma', 'PATIENT_LNAME': 'Perez', 'BLOOD_TYPE': 'A+', 'PHONE': '345-678-9012', 'EMAIL': 'emma.perez@example.com', 'GENDER': 'Female', 'POLICY_NUMBER': 'POL010', 'BIRTHDAY': '1992-01-05'}]
# Neo4j:
# <neo4j._sync.work.result.Result object at 0x11929fed0>
#
# Tempo de execução:
# - Oracle: 0.0159311295
# - Mongo: 0.0002019405
# - Neo4j: 0.0897679329
# Utilização de cpu:
# - Oracle: -0.2
# - Mongo: 0.0
# - Neo4j: 0.0
# Utilização de memória:
# - Oracle: 8192
# - Mongo: 20480
# - Neo4j: 147456

# %% [markdown]
# ## Query 4
# **Buscar as informações do doctor de id 24.**

# %%
num = "4"
queries[num] = {
    "Query": "Buscar as informações do doctor de id 24.",
    "oracleTime": -1,
    "oracleOutput": "",
    "oracleCPU": -1,
    "oracleMEM": -1,
    "mongoTime": -1,
    "mongoOutput": "",
    "mongoCPU": -1,
    "mongoMEM": -1,
    "neo4jTime": -1,
    "neo4jOutput": "",
    "neo4jCPU": -1,
    "neo4jMEM": -1
}

# Executar a query 4
# oracle
cpu_before, mem_before = monitor_usage()
start = time.time()
cursor = oracle_connection.cursor()
cursor.execute("""SELECT 
                doctor.*, 
                staff.*, 
                department.*
            FROM 
                doctor
            JOIN 
                staff ON doctor.emp_id = staff.emp_id
            JOIN 
                department ON staff.iddepartment = department.iddepartment
            WHERE 
                doctor.emp_id = 24
            """)
result = cursor.fetchall()
end = time.time()
cpu_after, mem_after = monitor_usage()
queries[num]["oracleTime"] = f"{end - start:.10f}"
queries[num]["oracleOutput"] = result
queries[num]["oracleCPU"] = cpu_after - cpu_before
queries[num]["oracleMEM"] = mem_after - mem_before

# mongo
cpu_before, mem_before = monitor_usage()
start = time.time()
result = mongo_collection.find(
    { "EPISODE.APPOINTMENT.DOCTOR.EMP_ID": 24 }, 
    {
        "_id": 0,
        "EPISODE.APPOINTMENT.DOCTOR.$": 1
    }
)
end = time.time()
cpu_after, mem_after = monitor_usage()
queries[num]["mongoTime"] = f"{end - start:.10f}"
queries[num]["mongoOutput"] = list(result)
queries[num]["mongoCPU"] = cpu_after - cpu_before
queries[num]["mongoMEM"] = mem_after - mem_before

# neo4j
cpu_before, mem_before = monitor_usage()
start = time.time()
cypher_query = """
MATCH (d:Doctor)-[:EMPLOYEE]->(s:Staff)-[:MEMBER_OF]->(dep:Department)
WHERE d.emp_id = 24
RETURN d, s, dep
"""
result = execute_query(cypher_query)
end = time.time()
cpu_after, mem_after = monitor_usage()

queries[num]["neo4jTime"] = f"{end - start:.10f}"
queries[num]["neo4jOutput"] = result
queries[num]["neo4jCPU"] = cpu_after - cpu_before
queries[num]["neo4jMEM"] = mem_after - mem_before

# Imprimir os resultados da query 4
print_results(num)
# Out:
# Query 4
#
# Oracle:
# [(24, 'PhD', 24, 'James', 'Carpenter', datetime.datetime(2019, 7, 10, 0, 0), datetime.datetime(2022, 1, 5, 0, 0), 'christineguzman@example.com', 'West Brianshire, NE 37671"', 124291244, 20, 'N', 20, 'Mia Garcia', 'Hematology', 4)]
# Mongo:
# [{'EPISODE': [{'APPOINTMENT': [{'DOCTOR': [{'QUALIFICATIONS': 'PhD', 'EMP_ID': 24, 'EMP_FNAME': 'James', 'EMP_LNAME': 'Carpenter', 'DATE_JOINING': '2019-07-10', 'DATE_SEPERATION': '2022-01-05', 'EMAIL': 'christineguzman@example.com', 'ADDRESS': 'West Brianshire, NE 37671"', 'SSN': 124291244, 'IS_ACTIVE_STATUS': 'N', 'DEPARTMENT': [{'IDDEPARTMENT': 20, 'DEPT_HEAD': 'Mia Garcia', 'DEPT_NAME': 'Hematology', 'EMP_COUNT': 4}]}]}]}]}, {'EPISODE': [{'APPOINTMENT': [{'DOCTOR': [{'QUALIFICATIONS': 'PhD', 'EMP_ID': 24, 'EMP_FNAME': 'James', 'EMP_LNAME': 'Carpenter', 'DATE_JOINING': '2019-07-10', 'DATE_SEPERATION': '2022-01-05', 'EMAIL': 'christineguzman@example.com', 'ADDRESS': 'West Brianshire, NE 37671"', 'SSN': 124291244, 'IS_ACTIVE_STATUS': 'N', 'DEPARTMENT': [{'IDDEPARTMENT': 20, 'DEPT_HEAD': 'Mia Garcia', 'DEPT_NAME': 'Hematology', 'EMP_COUNT': 4}]}]}]}]}, {'EPISODE': [{'APPOINTMENT': [{'DOCTOR': [{'QUALIFICATIONS': 'PhD', 'EMP_ID': 24, 'EMP_FNAME': 'James', 'EMP_LNAME': 'Carpenter', 'DATE_JOINING': '2019-07-10', 'DATE_SEPERATION': '2022-01-05', 'EMAIL': 'christineguzman@example.com', 'ADDRESS': 'West Brianshire, NE 37671"', 'SSN': 124291244, 'IS_ACTIVE_STATUS': 'N', 'DEPARTMENT': [{'IDDEPARTMENT': 20, 'DEPT_HEAD': 'Mia Garcia', 'DEPT_NAME': 'Hematology', 'EMP_COUNT': 4}]}]}]}]}, {'EPISODE': [{'APPOINTMENT': [{'DOCTOR': [{'QUALIFICATIONS': 'PhD', 'EMP_ID': 24, 'EMP_FNAME': 'James', 'EMP_LNAME': 'Carpenter', 'DATE_JOINING': '2019-07-10', 'DATE_SEPERATION': '2022-01-05', 'EMAIL': 'christineguzman@example.com', 'ADDRESS': 'West Brianshire, NE 37671"', 'SSN': 124291244, 'IS_ACTIVE_STATUS': 'N', 'DEPARTMENT': [{'IDDEPARTMENT': 20, 'DEPT_HEAD': 'Mia Garcia', 'DEPT_NAME': 'Hematology', 'EMP_COUNT': 4}]}]}]}]}]
# Neo4j:
# <neo4j._sync.work.result.Result object at 0x1192ae590>
#
# Tempo de execução:
# - Oracle: 0.0082070827
# - Mongo: 0.0001320839
# - Neo4j: 0.3975198269
# Utilização de cpu:
# - Oracle: -0.09999999999999998
# - Mongo: 0.0
# - Neo4j: 0.0
# Utilização de memória:
# - Oracle: 8192
# - Mongo: 0
# - Neo4j: 8192

# %% [markdown]
# ## Query 5
# **Calcula a soma cumulativa dos custos por paciente.**

# %%
num = "5"
queries[num] = {
    "Query": "Calcula a soma cumulativa dos custos por paciente.",
    "oracleTime": -1,
    "oracleOutput": "",
    "oracleCPU": -1,
    "oracleMEM": -1,
    "mongoTime": -1,
    "mongoOutput": "",
    "mongoCPU": -1,
    "mongoMEM": -1,
    "neo4jTime": -1,
    "neo4jOutput": "",
    "neo4jCPU": -1,
    "neo4jMEM": -1
}

# Executar a query 5
# oracle
cpu_before, mem_before = monitor_usage()
start = time.time()
cursor = oracle_connection.cursor()
cursor.execute("""SELECT 
                    p.idpatient, 
                    p.patient_fname, 
                    p.patient_lname, 
                    COALESCE(SUM(b.total), 0) AS total_bill_cost
                FROM 
                    patient p
                LEFT JOIN 
                    episode e ON p.idpatient = e.patient_idpatient
                LEFT JOIN 
                    bill b ON e.idepisode = b.idepisode
                GROUP BY 
                    p.idpatient, p.patient_fname, p.patient_lname
                ORDER BY 
                    p.idpatient
""")
result = cursor.fetchall()
end = time.time()
cpu_after, mem_after = monitor_usage()
queries[num]["oracleTime"] = f"{end - start:.10f}"
queries[num]["oracleOutput"] = result
queries[num]["oracleCPU"] = cpu_after - cpu_before
queries[num]["oracleMEM"] = mem_after - mem_before

# mongo
cpu_before, mem_before = monitor_usage()
start = time.time()
result = mongo_collection.aggregate([
    { "$unwind": "$EPISODE" },
    { "$unwind": { "path": "$EPISODE.BILL", "preserveNullAndEmptyArrays": True } },
    {
        "$group": {
            "_id": "$IDPATIENT",
            "patientName": { "$first": { "$concat": ["$PATIENT_FNAME", " ", "$PATIENT_LNAME"] } },
            "totalBill": { "$sum": { "$ifNull": ["$EPISODE.BILL.TOTAL", 0] } }
        }
    },
    { "$sort": { "_id": 1 } },
    {
        "$project": {
            "_id": 1,
            "patientName": 1,
            "totalBill": 1
        }
    }
])

end = time.time()
cpu_after, mem_after = monitor_usage()
queries[num]["mongoTime"] = f"{end - start:.10f}"
queries[num]["mongoOutput"] = list(result)
queries[num]["mongoCPU"] = cpu_after - cpu_before
queries[num]["mongoMEM"] = mem_after - mem_before

# neo4j

cpu_before, mem_before = monitor_usage()
start = time.time()
cypher_query = """
MATCH (p:Patient)
OPTIONAL MATCH (p)-[:HAS_EPISODE]->(e:Episode)
OPTIONAL MATCH (e)-[:HAS_BILL]->(b:Bill)
WITH p, SUM(b.total) AS total_bill_cost
RETURN p.idpatient, p.patient_fname, p.patient_lname, COALESCE(total_bill_cost, 0) AS total_bill_cost
ORDER BY p.idpatient
"""
result = execute_query(cypher_query)
end = time.time()
cpu_after, mem_after = monitor_usage()


queries[num]["neo4jTime"] = f"{end - start:.10f}"
queries[num]["neo4jOutput"] = result
queries[num]["neo4jCPU"] = cpu_after - cpu_before
queries[num]["neo4jMEM"] = mem_after - mem_before

# Imprimir os resultados da query 5
print_results(num)
# Out:
# Query 5
#
# Oracle:
# [(1, 'John', 'Doe', 0), (2, 'Jane', 'Smith', 10203.34), (3, 'Michael', 'Johnson', 3655), (4, 'Emily', 'Brown', 0), (5, 'William', 'Martinez', 7350), (6, 'Sophia', 'Garcia', 4570), (7, 'James', 'Lopez', 0), (8, 'Olivia', 'Lee', 0), (9, 'Benjamin', 'Gonzalez', 7845), (10, 'Emma', 'Perez', 0), (11, 'Jacob', 'Rodriguez', 6330), (12, 'Isabella', 'Hernandez', 0), (13, 'Ethan', 'Lopez', 0), (14, 'Mia', 'Gomez', 1980), (15, 'Alexander', 'Diaz', 0), (16, 'Ava', 'Rivera', 0), (17, 'William', 'Smith', 0), (18, 'Sophia', 'Gonzalez', 0), (19, 'Michael', 'Martinez', 0), (20, 'Olivia', 'Perez', 0), (21, 'Liam', 'Torres', 0), (22, 'Emma', 'Flores', 0), (23, 'Noah', 'Ramirez', 0), (24, 'Olivia', 'Gutierrez', 0), (25, 'William', 'Nguyen', 550), (26, 'Ava', 'Tran', 0), (27, 'James', 'Kim', 8370), (28, 'Sophia', 'Le', 13496.36), (29, 'Logan', 'Do', 10092.73), (30, 'Amelia', 'Huynh', 0), (31, 'Ethan', 'Vo', 340), (32, 'Isabella', 'Phan', 0), (33, 'Mason', 'Duong', 11343.57), (34, 'Oliver', 'Truong', 0), (35, 'Charlotte', 'Ngo', 0), (36, 'Lucas', 'Vuong', 0), (37, 'Amelia', 'Pham', 0), (38, 'Benjamin', 'Le', 0), (39, 'Evelyn', 'Bui', 0), (40, 'Alexander', 'Ho', 0), (41, 'Sophia', 'Nguyen', 0), (42, 'Jackson', 'Tran', 7604.6), (43, 'Madison', 'Dinh', 0), (44, 'Aiden', 'Vo', 0), (45, 'Scarlett', 'Huynh', 0), (46, 'Daniel', 'Do', 0), (47, 'Victoria', 'Lam', 0), (48, 'Joseph', 'Mai', 0), (49, 'Natalie', 'Trinh', 0), (50, 'Samuel', 'Vo', 0), (51, 'Olivia', 'Nguyen', 0), (52, 'Ethan', 'Tran', 1635), (53, 'Emma', 'Dinh', 0), (54, 'Noah', 'Vo', 12020), (55, 'Isabella', 'Huynh', 14813.35), (56, 'William', 'Do', 1980), (57, 'Sophia', 'Lam', 11130.1), (58, 'James', 'Mai', 8655.88), (59, 'Charlotte', 'Trinh', 0), (60, 'Logan', 'Vo', 610), (61, 'Ava', 'Nguyen', 0), (62, 'Mason', 'Pham', 6425), (63, 'Harper', 'Ho', 1720), (64, 'Elijah', 'Truong', 4700), (65, 'Amelia', 'Le', 2350), (66, 'Benjamin', 'Ngo', 3620), (67, 'Evelyn', 'Ly', 0), (68, 'Alexander', 'Dang', 11359.58), (69, 'Abigail', 'Vuong', 1425), (70, 'Michael', 'Duong', 9275), (71, 'Olivia', 'Tran', 0), (72, 'James', 'Vo', 2300.42), (73, 'Emma', 'Luu', 5614.49), (74, 'Lucas', 'Ha', 0), (75, 'Avery', 'Hoang', 14978.98), (76, 'William', 'Bui', 8665), (77, 'Sophia', 'Phan', 0), (78, 'Logan', 'Trinh', 4200), (79, 'Mia', 'Nguyen', 0), (80, 'Benjamin', 'Vu', 0), (81, 'Ella', 'Le', 0), (82, 'Alexander', 'Ho', 7422.57), (83, 'Sofia', 'Pham', 0), (84, 'Henry', 'Tran', 690), (85, 'Scarlett', 'Dang', 1090), (86, 'Ethan', 'Duong', 0), (87, 'Madison', 'Nguyen', 9129.27), (88, 'Jacob', 'Lam', 0), (89, 'Amelia', 'Tran', 5886.11), (90, 'Michael', 'Do', 3250)]
# Mongo:
# [{'_id': 1, 'patientName': 'John Doe', 'totalBill': 0}, {'_id': 2, 'patientName': 'Jane Smith', 'totalBill': 10203.34}, {'_id': 3, 'patientName': 'Michael Johnson', 'totalBill': 3655.0}, {'_id': 4, 'patientName': 'Emily Brown', 'totalBill': 0}, {'_id': 5, 'patientName': 'William Martinez', 'totalBill': 7350.0}, {'_id': 6, 'patientName': 'Sophia Garcia', 'totalBill': 4570.0}, {'_id': 7, 'patientName': 'James Lopez', 'totalBill': 0}, {'_id': 8, 'patientName': 'Olivia Lee', 'totalBill': 0}, {'_id': 9, 'patientName': 'Benjamin Gonzalez', 'totalBill': 7845.0}, {'_id': 10, 'patientName': 'Emma Perez', 'totalBill': 0}, {'_id': 11, 'patientName': 'Jacob Rodriguez', 'totalBill': 6330.0}, {'_id': 12, 'patientName': 'Isabella Hernandez', 'totalBill': 0}, {'_id': 13, 'patientName': 'Ethan Lopez', 'totalBill': 0}, {'_id': 14, 'patientName': 'Mia Gomez', 'totalBill': 1980.0}, {'_id': 15, 'patientName': 'Alexander Diaz', 'totalBill': 0}, {'_id': 16, 'patientName': 'Ava Rivera', 'totalBill': 0}, {'_id': 17, 'patientName': 'William Smith', 'totalBill': 0}, {'_id': 18, 'patientName': 'Sophia Gonzalez', 'totalBill': 0}, {'_id': 19, 'patientName': 'Michael Martinez', 'totalBill': 0}, {'_id': 20, 'patientName': 'Olivia Perez', 'totalBill': 0}, {'_id': 21, 'patientName': 'Liam Torres', 'totalBill': 0}, {'_id': 22, 'patientName': 'Emma Flores', 'totalBill': 0}, {'_id': 23, 'patientName': 'Noah Ramirez', 'totalBill': 0}, {'_id': 24, 'patientName': 'Olivia Gutierrez', 'totalBill': 0}, {'_id': 25, 'patientName': 'William Nguyen', 'totalBill': 550.0}, {'_id': 26, 'patientName': 'Ava Tran', 'totalBill': 0}, {'_id': 27, 'patientName': 'James Kim', 'totalBill': 8370.0}, {'_id': 28, 'patientName': 'Sophia Le', 'totalBill': 13496.36}, {'_id': 29, 'patientName': 'Logan Do', 'totalBill': 10092.73}, {'_id': 30, 'patientName': 'Amelia Huynh', 'totalBill': 0}, {'_id': 31, 'patientName': 'Ethan Vo', 'totalBill': 340.0}, {'_id': 32, 'patientName': 'Isabella Phan', 'totalBill': 0}, {'_id': 33, 'patientName': 'Mason Duong', 'totalBill': 11343.57}, {'_id': 34, 'patientName': 'Oliver Truong', 'totalBill': 0}, {'_id': 35, 'patientName': 'Charlotte Ngo', 'totalBill': 0}, {'_id': 36, 'patientName': 'Lucas Vuong', 'totalBill': 0}, {'_id': 37, 'patientName': 'Amelia Pham', 'totalBill': 0}, {'_id': 38, 'patientName': 'Benjamin Le', 'totalBill': 0}, {'_id': 39, 'patientName': 'Evelyn Bui', 'totalBill': 0}, {'_id': 40, 'patientName': 'Alexander Ho', 'totalBill': 0}, {'_id': 41, 'patientName': 'Sophia Nguyen', 'totalBill': 0}, {'_id': 42, 'patientName': 'Jackson Tran', 'totalBill': 7604.6}, {'_id': 43, 'patientName': 'Madison Dinh', 'totalBill': 0}, {'_id': 44, 'patientName': 'Aiden Vo', 'totalBill': 0}, {'_id': 45, 'patientName': 'Scarlett Huynh', 'totalBill': 0}, {'_id': 46, 'patientName': 'Daniel Do', 'totalBill': 0}, {'_id': 47, 'patientName': 'Victoria Lam', 'totalBill': 0}, {'_id': 48, 'patientName': 'Joseph Mai', 'totalBill': 0}, {'_id': 49, 'patientName': 'Natalie Trinh', 'totalBill': 0}, {'_id': 50, 'patientName': 'Samuel Vo', 'totalBill': 0}, {'_id': 51, 'patientName': 'Olivia Nguyen', 'totalBill': 0}, {'_id': 52, 'patientName': 'Ethan Tran', 'totalBill': 1635.0}, {'_id': 53, 'patientName': 'Emma Dinh', 'totalBill': 0}, {'_id': 54, 'patientName': 'Noah Vo', 'totalBill': 12020.0}, {'_id': 55, 'patientName': 'Isabella Huynh', 'totalBill': 14813.35}, {'_id': 56, 'patientName': 'William Do', 'totalBill': 1980.0}, {'_id': 57, 'patientName': 'Sophia Lam', 'totalBill': 11130.1}, {'_id': 58, 'patientName': 'James Mai', 'totalBill': 8655.88}, {'_id': 59, 'patientName': 'Charlotte Trinh', 'totalBill': 0}, {'_id': 60, 'patientName': 'Logan Vo', 'totalBill': 610.0}, {'_id': 61, 'patientName': 'Ava Nguyen', 'totalBill': 0}, {'_id': 62, 'patientName': 'Mason Pham', 'totalBill': 6425.0}, {'_id': 63, 'patientName': 'Harper Ho', 'totalBill': 1720.0}, {'_id': 64, 'patientName': 'Elijah Truong', 'totalBill': 4700.0}, {'_id': 65, 'patientName': 'Amelia Le', 'totalBill': 2350.0}, {'_id':  ...
# Neo4j:
# <neo4j._sync.work.result.Result object at 0x1192c45d0>
#
# Tempo de execução:
# - Oracle: 0.0408780575
# - Mongo: 0.0589787960
# - Neo4j: 0.2842910290
# Utilização de cpu:
# - Oracle: -0.2
# - Mongo: 0.0
# - Neo4j: -0.1
# Utilização de memória:
# - Oracle: 28672
# - Mongo: 49152
# - Neo4j: 16384

# %% [markdown]
# ## Tempos de execução, Uso de CPU, Uso de memória

# %%
for key in queries:
    print(f"Query {key}: {queries[key]['Query']}")
    print(f"OracleTime: {queries[key]['oracleTime']}")
    print(f"MongoTime: {queries[key]['mongoTime']}")
    print(f"neo4jTime: {queries[key]['neo4jTime']}")
    print(f"OracleCPU: {queries[key]['oracleCPU']}")
    print(f"MongoCPU: {queries[key]['mongoCPU']}")
    print(f"neo4jCPU: {queries[key]['neo4jCPU']}")
    print(f"OracleMEM: {queries[key]['oracleMEM']}")
    print(f"MongoMEM: {queries[key]['mongoMEM']}")
    print(f"neo4jMEM: {queries[key]['neo4jMEM']}")       
    print()
# Out:
# Query 1: Selecionar todas as informações de todos os membros do Staff (doctors, nurses, technicians).
# OracleTime: 0.0050051212
# MongoTime: 0.0001618862
# neo4jTime: 0.0335609913
# OracleCPU: -0.2
# MongoCPU: 0.0
# neo4jCPU: 0.1
# OracleMEM: 188416
# MongoMEM: 0
# neo4jMEM: 495616
#
# Query 2: Selecionar todos os patients onde o blood_type é 'A+'
# OracleTime: 0.0089859962
# MongoTime: 0.0001583099
# neo4jTime: 0.1698651314
# OracleCPU: -0.3
# MongoCPU: 0.2
# neo4jCPU: 0.2
# OracleMEM: -13758464
# MongoMEM: -21368832
# neo4jMEM: -425984
#
# Query 3: Buscar as informações do paciente de id 10.
# OracleTime: 0.0159311295
# MongoTime: 0.0002019405
# neo4jTime: 0.0897679329
# OracleCPU: -0.2
# MongoCPU: 0.0
# neo4jCPU: 0.0
# OracleMEM: 8192
# MongoMEM: 20480
# neo4jMEM: 147456
#
# Query 4: Buscar as informações do doctor de id 24.
# OracleTime: 0.0082070827
# MongoTime: 0.0001320839
# neo4jTime: 0.3975198269
# OracleCPU: -0.09999999999999998
# MongoCPU: 0.0
# neo4jCPU: 0.0
# OracleMEM: 8192
# MongoMEM: 0
# neo4jMEM: 8192
#
# Query 5: Calcula a soma cumulativa dos custos por paciente.
# OracleTime: 0.0408780575
# MongoTime: 0.0589787960
# neo4jTime: 0.2842910290
# OracleCPU: -0.2
# MongoCPU: 0.0
# neo4jCPU: -0.1
# OracleMEM: 28672
# MongoMEM: 49152
# neo4jMEM: 16384
