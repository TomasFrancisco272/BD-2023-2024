# %% [markdown]
# # Conecções

# %%
import time
import psutil
from neo4j import GraphDatabase

def connect_to_neo4j():
    try:
        uri = "bolt://localhost:7687"
        user = "neo4j"
        password = "12345678"
        driver = GraphDatabase.driver(uri, auth=(user, password))
        print("Conexão bem sucedida ao Neo4j!")
        return driver
    except Exception:
        print("Erro ao conectar ao Neo4j")
        return

# Conectar ao Neo4j
neo4j_connection = connect_to_neo4j()

def monitor_usage():
    process = psutil.Process()
    cpu_usage = process.cpu_percent(interval=1)
    memory_usage = process.memory_info().rss
    return cpu_usage, memory_usage

def execute_query(query):
    with neo4j_connection.session() as session:
        result = session.run(query)
        return list(result)

queries = {}
# Out:
# Conexão bem sucedida ao Neo4j!

# %% [markdown]
# ## Query 1
# **Selecionar todas as informações de todos os membros do Staff (doctors, nurses, technicians).**

# %%
num = "1"
queries[num] = {
    "Query": "Selecionar todas as informações de todos os membros do Staff (doctors, nurses, technicians).",
    "neo4jTime": -1,
    "neo4jOutput": "",
    "neo4jCPU": -1,
    "neo4jMEM": -1
}

cpu_before, mem_before = monitor_usage()
start = time.time()
cypher_query = """
MATCH (e:Employee)
RETURN e
"""
result = execute_query(cypher_query)
end = time.time()
cpu_after, mem_after = monitor_usage()

queries[num]["neo4jTime"] = f"{end - start:.10f}"
queries[num]["neo4jOutput"] = result
queries[num]["neo4jCPU"] = cpu_after - cpu_before
queries[num]["neo4jMEM"] = mem_after - mem_before

# Imprimir os resultados da query 1
for record in result:
        employee = record["e"]
        print(f"id_employee: {employee['id_employee']}")
        print(f"First Name: {employee['fname']}")
        print(f"Last Name: {employee['lname']}")
        print(f"Job: {employee['job']}")
        print(f"Date Joining: {employee['data_joining']}")
        print(f"Date Separation: {employee['data_seperation']}")
        print(f"Email: {employee['email']}")
        print(f"Address: {employee['address']}")
        print(f"SSN: {employee['ssn']}")
        print(f"Is Active: {employee['is_active_status']}")
        print(f"Qualifications: {employee.get('qualifications', 'N/A')}")
        print(f"Department ID: {employee.get('department_id', 'N/A')}")
        print(f"Department Head: {employee.get('department_head', 'N/A')}")
        print(f"Department Name: {employee.get('department_name', 'N/A')}")
        print(f"Department Employee Count: {employee.get('department_emp_count', 'N/A')}")
        print("=" * 40)

print("Tempo de execução:")
print("- Neo4j:",queries[num]["neo4jTime"])
print("Utilização de cpu:")
print("- Neo4j:",queries[num]["neo4jCPU"])
print("Utilização de memória:")
print("- Neo4j:",queries[num]["neo4jMEM"])
# Out:
# id_employee: 1
# First Name: Jillian
# Last Name: Gordon
# Job: Doctor
# Date Joining: 2018-08-25T00:00:00.000000000
# Date Separation: None
# Email: juan14@example.net
# Address: "435 Dylan Neck Suite 993
# SSN: 329594711
# Is Active: Y
# Qualifications: MD
# Department ID: 25
# Department Head: Lucas Lopez
# Department Name: Rheumatology
# Department Employee Count: 5
# ========================================
# id_employee: 2
# First Name: James
# Last Name: Williams
# Job: Doctor
# Date Joining: 2018-04-10T00:00:00.000000000
# Date Separation: 2023-01-05T00:00:00.000000000
# Email: henryjennifer@example.net
# Address: Kleinhaven, CT 37220"
# SSN: 527613638
# Is Active: N
# Qualifications: PhD
# Department ID: 16
# Department Head: Sophia Lopez
# Department Name: Ophthalmology
# Department Employee Count: 5
# ========================================
# id_employee: 3
# First Name: Joshua
# Last Name: Carter
# Job: Doctor
# Date Joining: 2018-03-15T00:00:00.000000000
# Date Separation: None
# Email: michael82@example.org
# Address: "Unit 4429 Box 5356
# SSN: 724148400
# Is Active: Y
# Qualifications: MD
# Department ID: 27
# Department Head: Daniel Lee
# Department Name: Psychiatry
# Department Employee Count: 4
# ========================================
# id_employee: 4
# First Name: Joe
# Last Name: Ferguson
# Job: Nurse
# Date Joining: 2018-08-10T00:00:00.000000000
# Date Separation: None
# Email: vsullivan@example.org
# Address: DPO AE 27029"
# SSN: 531094042
# Is Active: Y
# Qualifications: N/A
# Department ID: 17
# Department Head: Ethan Brown
# Department Name: Gynecology
# Department Employee Count: 5
# ========================================
# id_employee: 5
# First Name: Travis
# Last Name: Ramos
# Job: Nurse
# Date Joining: 2019-10-15T00:00:00.000000000
# Date Separation: None
# Email: leah21@example.org
# Address: "12795 Solis Landing Apt. 269
# SSN: 857991076
# Is Active: Y
# Qualifications: N/A
# Department ID: 21
# Department Head: James Martinez
# Department Name: Endocrinology
# Department Employee Count: 4
# ========================================
# id_employee: 6
# First Name: Lisa
# Last Name: Hayes
# Job: Doctor
# Date Joining: 2023-05-10T00:00:00.000000000
# Date Separation: None
# Email: mprice@example.com
# Address: Trevorfurt, IN 02637"
# SSN: 685569160
# Is Active: Y
# Qualifications: PhD
# Department ID: 1
# Department Head: John Smith
# Department Name: Cardiology_1
# Department Employee Count: 2
# ========================================
# id_employee: 7
# First Name: Dawn
# Last Name: Hopkins
# Job: Nurse
# Date Joining: 2019-11-28T00:00:00.000000000
# Date Separation: 2022-01-05T00:00:00.000000000
# Email: jenkinsheather@example.com
# Address: "02444 Anderson Street Suite 139
# SSN: 215259434
# Is Active: N
# Qualifications: N/A
# Department ID: 16
# Department Head: Sophia Lopez
# Department Name: Ophthalmology
# Department Employee Count: 5
# ========================================
# id_employee: 8
# First Name: Dawn
# Last Name: Roberts
# Job: Doctor
# Date Joining: 2019-12-01T00:00:00.000000000
# Date Separation: None
# Email: laurie35@example.net
# Address: Leeville, SD 39088"
# SSN: 391666874
# Is Active: Y
# Qualifications: MD
# Department ID: 14
# Department Head: Isabella Hernandez
# Department Name: Radiology
# Department Employee Count: 5
# ========================================
# id_employee: 9
# First Name: Jessica
# Last Name: Jones
# Job: Doctor
# Date Joining: 2019-01-05T00:00:00.000000000
# Date Separation: None
# Email: larrykrause@example.net
# Address: "548 Bonilla Extensions
# SSN: 410402409
# Is Active: Y
# Qualifications: MD
# Department ID: 26
# Department Head: Emma Brown
# Department Name: Dentistry
# Department Employee Count: 10
# ========================================
# id_employee: 10
# First Name: Rachel
# Last Name: Wilson
# Job: Nurse
# Date Joining: 2019-07-10T00:00:00.000000000
# Date Separation: 2022-01-05T00:00:00.000000000
# Email: jenna85@example.org
# Address: West Robertshire, MH 77607"
# SSN: 745100367
# Is Active: N
# Qualifications: N/A
# Department ID: 20
# Department Head: Mia Garcia
# Department Name: Hematology
# Department Employee Count: 4
# ========================================
# id_employee: 11
# First Name: Kimberly
# Last Name: Blankenship
# Job: Doctor
# Date Joining: 2019-01-05T00:00:00.000000000
# Date Separation: None
# Email: melissa35@example.org
# Address: "641 Tyler Fork Suite 201
# SSN: 281673265
# Is Active: Y
# Qualifications: MD
# Department ID: 26
# Department Head: Emma Brown
# Department Name: Dentistry
# Department Employee Count: 10
# ========================================
# id_employee: 12
# First Name: Keith
# Last Name: Simmons
# Job: Nurse
# Date Joining: 2018-12-01T00:00:00.000000000
# Date Separation: None
# Email: tylerthompson@example.org
# Address: Browntown, WY 84829"
# SSN: 899470207
# Is Active: Y
# Qualifications: N/A
# Department ID: 14
# Department Head: Isabella Hernandez
# Department Name: Radiology
# Department Employee Count: 5
# ========================================
# id_employee: 13
# First Name: William
# Last Name: Grant
# Job: Doctor
# Date Joining: 2019-07-10T00:00:00.000000000
# Date Separation: 2022-01-05T00:00:00.000000000
# Email: seanlyons@example.org
# Address: "41829 Andrew Course Apt. 567
# SSN: 804408507
# Is Active: N
# Qualifications: PhD
# Department ID: 20
# Department Head: Mia Garcia
# Department Name: Hematology
# Department Employee Count: 4
# ========================================
# id_employee: 14
# First Name: Andrew
# Last Name: Deleon
# Job: Doctor
# Date Joining: 2018-09-15T00:00:00.000000000
# Date Separation: None
# Email: dominiquemcdaniel@example.com
# Address: North Kayla, ME 24616"
# SSN: 184426607
# Is Active: Y
# Qualifications: MD
# Department ID: 27
# Department Head: Daniel Lee
# Department Name: Psychiatry
# Department Employee Count: 4
# ========================================
# id_employee: 15
# First Name: Emily
# Last Name: Rowe
# Job: Doctor
# Date Joining: 2018-04-10T00:00:00.000000000
# Date Separation: 2023-01-05T00:00:00.000000000
# Email: thompsonsuzanne@example.org
# Address: "2191 Little Fall Apt. 951
# SSN: 457794054
# Is Active: N
# Qualifications: MD
# Department ID: 16
# Department Head: Sophia Lopez
# Department Name: Ophthalmology
# Department Employee Count: 5
# ========================================
# id_employee: 16
# First Name: Kenneth
# Last Name: Ayers
# Job: Nurse
# Date Joining: 2018-08-25T00:00:00.000000000
# Date Separation: None
# Email: emily66@example.net
# Address: New Sarahberg, IA 31150"
# SSN: 719506165
# Is Active: Y
# Qualifications: N/A
# Department ID: 25
# Department Head: Lucas Lopez
# Department Name: Rheumatology
# Department Employee Count: 5
# ========================================
# id_employee: 17
# First Name: Daniel
# Last Name: Mills
# Job: Doctor
# Date Joining: 2018-08-10T00:00:00.000000000
# Date Separation: None
# Email: lthompson@example.org
# Address: "389 Jeffrey Mountain
# SSN: 481584738
# Is Active: Y
# Qualifications: PhD
# Department ID: 17
# Department Head: Ethan Brown
# Department Name: Gynecology
# Department Employee Count: 5
# ========================================
# id_employee: 18
# First Name: Tina
# Last Name: Gilbert
# Job: Nurse
# Date Joining: 2019-10-15T00:00:00.000000000
# Date Separation: None
# Email: danjones@example.net
# Address: Lindaview, MA 29212"
# SSN: 522524152
# Is Active: Y
# Qualifications: N/A
# Department ID: 21
# Department Head: James Martinez
# Department Name: Endocrinology
# Department Employee Count: 4
# ========================================
# id_employee: 19
# First Name: Scott
# Last Name: Holmes
# Job: Doctor
# Date Joining: 2023-05-10T00:00:00.000000000
# Date Separation: None
# Email: tammy41@example.net
# Address: "107 Velasquez Corner
# SSN: 105899430
# Is Active: Y
# Qualifications: MD
# Department ID: 1
# Department Head: John Smith
# Department Name: Cardiology_1
# Department Employee Count: 2
# ========================================
# id_employee: 20
# First Name: Jennifer
# Last Name: Ball
# Job: Nurse
# Date Joining: 2019-11-28T00:00:00.000000000
# Date Separation: 2022-01-05T00:00:00.000000000
# Email: brandymartinez@example.com
# Address: Lake Tina, IA 30662"
# SSN: 404767927
# Is Active: N
# Qualifications: N/A
# Department ID: 16
# Department Head: Sophia Lopez
# Department Name: Ophthalmology
# Department Employee Count: 5
# ========================================
# id_employee: 21
# First Name: Stacy
# Last Name: Logan
# Job: Nurse
# Date Joining: 2019-12-01T00:00:00.000000000
# Date Separation: None
# Email: uturner@example.net
# Address: "771 Jennifer Bypass
# SSN: 633814140
# Is Active: Y
# Qualifications: N/A
# Department ID: 14
# Department Head: Isabella Hernandez
# Department Name: Radiology
# Department Employee Count: 5
# ========================================
# id_employee: 22
# First Name: Jeffrey
# Last Name: Jones
# Job: Nurse
# Date Joining: 2019-01-05T00:00:00.000000000
# Date Separation: None
# Email: uscott@example.com
# Address: Candicefurt, AS 18171"
# SSN: 258505600
# Is Active: Y
# Qualifications: N/A
# Department ID: 26
# Department Head: Emma Brown
# Department Name: Dentistry
# Department Employee Count: 10
# ========================================
# id_employee: 23
# First Name: Cheryl
# Last Name: Christensen
# Job: Nurse
# Date Joining: 2018-12-01T00:00:00.000000000
# Date Separation: None
# Email: morganstephen@example.com
# Address: "219 Tammy Meadows
# SSN: 260911313
# Is Active: Y
# Qualifications: N/A
# Department ID: 14
# Department Head: Isabella Hernandez
# Department Name: Radiology
# Department Employee Count: 5
# ========================================
# id_employee: 24
# First Name: James
# Last Name: Carpenter
# Job: Doctor
# Date Joining: 2019-07-10T00:00:00.000000000
# Date Separation: 2022-01-05T00:00:00.000000000
# Email: christineguzman@example.com
# Address: West Brianshire, NE 37671"
# SSN: 124291244
# Is Active: N
# Qualifications: PhD
# Department ID: 20
# Department Head: Mia Garcia
# Department Name: Hematology
# Department Employee Count: 4
# ========================================
# id_employee: 25
# First Name: Matthew
# Last Name: Espinoza
# Job: Nurse
# Date Joining: 2018-09-15T00:00:00.000000000
# Date Separation: None
# Email: roger32@example.net
# Address: "1163 Ethan Underpass Apt. 901
# SSN: 402431746
# Is Active: Y
# Qualifications: N/A
# Department ID: 27
# Department Head: Daniel Lee
# Department Name: Psychiatry
# Department Employee Count: 4
# ========================================
# id_employee: 26
# First Name: Vickie
# Last Name: Gonzalez
# Job: Nurse
# Date Joining: 2018-04-10T00:00:00.000000000
# Date Separation: 2023-01-05T00:00:00.000000000
# Email: lolson@example.com
# Address: East Michael, CT 20442"
# SSN: 925078857
# Is Active: N
# Qualifications: N/A
# Department ID: 16
# Department Head: Sophia Lopez
# Department Name: Ophthalmology
# Department Employee Count: 5
# ========================================
# id_employee: 27
# First Name: Denise
# Last Name: Acosta
# Job: Nurse
# Date Joining: 2018-08-25T00:00:00.000000000
# Date Separation: None
# Email: emilylee@example.org
# Address: "844 Patel Keys
# SSN: 375062322
# Is Active: Y
# Qualifications: N/A
# Department ID: 25
# Department Head: Lucas Lopez
# Department Name: Rheumatology
# Department Employee Count: 5
# ========================================
# id_employee: 28
# First Name: Emily
# Last Name: Frederick
# Job: Nurse
# Date Joining: 2018-08-10T00:00:00.000000000
# Date Separation: None
# Email: caseyjoseph@example.com
# Address: Lake Lauren, ME 06845"
# SSN: 634799699
# Is Active: Y
# Qualifications: N/A
# Department ID: 17
# Department Head: Ethan Brown
# Department Name: Gynecology
# Department Employee Count: 5
# ========================================
# id_employee: 29
# First Name: Anthony
# Last Name: Larson
# Job: Nurse
# Date Joining: 2019-10-15T00:00:00.000000000
# Date Separation: None
# Email: richardsoncheryl@example.org
# Address: "98044 Wood Trafficway Suite 896
# SSN: 469016851
# Is Active: N
# Qualifications: N/A
# Department ID: 21
# Department Head: James Martinez
# Department Name: Endocrinology
# Department Employee Count: 4
# ========================================
# id_employee: 30
# First Name: Noah
# Last Name: Terry
# Job: Doctor
# Date Joining: 2023-05-10T00:00:00.000000000
# Date Separation: None
# Email: amandabooth@example.net
# Address: Billyhaven, KS 16701"
# SSN: 487128573
# Is Active: Y
# Qualifications: MD
# Department ID: 1
# Department Head: John Smith
# Department Name: Cardiology_1
# Department Employee Count: 2
# ========================================
# id_employee: 31
# First Name: Richard
# Last Name: Tran
# Job: Nurse
# Date Joining: 2019-11-28T00:00:00.000000000
# Date Separation: 2022-01-05T00:00:00.000000000
# Email: onelson@example.net
# Address: "924 Johnson Glens
# SSN: 501902807
# Is Active: N
# Qualifications: N/A
# Department ID: 16
# Department Head: Sophia Lopez
# Department Name: Ophthalmology
# Department Employee Count: 5
# ========================================
# id_employee: 32
# First Name: Nicole
# Last Name: Elliott
# Job: Nurse
# Date Joining: 2019-12-01T00:00:00.000000000
# Date Separation: None
# Email: miguelrogers@example.org
# Address: Steveshire, KS 14385"
# SSN: 155620842
# Is Active: Y
# Qualifications: N/A
# Department ID: 14
# Department Head: Isabella Hernandez
# Department Name: Radiology
# Department Employee Count: 5
# ========================================
# id_employee: 33
# First Name: David
# Last Name: Barber
# Job: Nurse
# Date Joining: 2019-01-05T00:00:00.000000000
# Date Separation: None
# Email: christinawalker@example.net
# Address: "0145 Bowers Fort Suite 027
# SSN: 340817770
# Is Active: Y
# Qualifications: N/A
# Department ID: 26
# Department Head: Emma Brown
# Department Name: Dentistry
# Department Employee Count: 10
# ========================================
# id_employee: 34
# First Name: Dillon
# Last Name: Jones
# Job: Doctor
# Date Joining: 2018-12-01T00:00:00.000000000
# Date Separation: None
# Email: joshuajohnson@example.net
# Address: South Deannaland, LA 85459"
# SSN: 833281856
# Is Active: Y
# Qualifications: MD
# Department ID: 14
# Department Head: Isabella Hernandez
# Department Name: Radiology
# Department Employee Count: 5
# ========================================
# id_employee: 35
# First Name: Diamond
# Last Name: Gonzalez
# Job: Nurse
# Date Joining: 2019-07-10T00:00:00.000000000
# Date Separation: 2022-01-05T00:00:00.000000000
# Email: sjoseph@example.com
# Address: "763 Rangel Roads Suite 571
# SSN: 525996493
# Is Active: N
# Qualifications: N/A
# Department ID: 20
# Department Head: Mia Garcia
# Department Name: Hematology
# Department Employee Count: 4
# ========================================
# id_employee: 36
# First Name: Deanna
# Last Name: Baker
# Job: Nurse
# Date Joining: 2018-09-15T00:00:00.000000000
# Date Separation: None
# Email: mcbridebriana@example.com
# Address: East Ryan, NY 85809"
# SSN: 616581558
# Is Active: Y
# Qualifications: N/A
# Department ID: 27
# Department Head: Daniel Lee
# Department Name: Psychiatry
# Department Employee Count: 4
# ========================================
# id_employee: 37
# First Name: Teresa
# Last Name: Harris
# Job: Nurse
# Date Joining: 2018-04-10T00:00:00.000000000
# Date Separation: 2023-01-05T00:00:00.000000000
# Email: bsalas@example.net
# Address: "971 Chavez Garden Suite 571
# SSN: 930993929
# Is Active: N
# Qualifications: N/A
# Department ID: 16
# Department Head: Sophia Lopez
# Department Name: Ophthalmology
# Department Employee Count: 5
# ========================================
# id_employee: 38
# First Name: Patrick
# Last Name: Sparks
# Job: Nurse
# Date Joining: 2018-08-25T00:00:00.000000000
# Date Separation: None
# Email: nelsonmark@example.org
# Address: Port Emily, NE 23873"
# SSN: 909543569
# Is Active: N
# Qualifications: N/A
# Department ID: 25
# Department Head: Lucas Lopez
# Department Name: Rheumatology
# Department Employee Count: 5
# ========================================
# id_employee: 39
# First Name: Lance
# Last Name: Scott
# Job: Nurse
# Date Joining: 2018-08-10T00:00:00.000000000
# Date Separation: None
# Email: peterdavis@example.com
# Address: "68405 Amanda Island
# SSN: 925578003
# Is Active: Y
# Qualifications: N/A
# Department ID: 17
# Department Head: Ethan Brown
# Department Name: Gynecology
# Department Employee Count: 5
# ========================================
# id_employee: 40
# First Name: Chelsea
# Last Name: Dodson
# Job: Nurse
# Date Joining: 2019-10-15T00:00:00.000000000
# Date Separation: None
# Email: daviscody@example.net
# Address: Lake Vickie, VI 12026"
# SSN: 642107275
# Is Active: Y
# Qualifications: N/A
# Department ID: 21
# Department Head: James Martinez
# Department Name: Endocrinology
# Department Employee Count: 4
# ========================================
# id_employee: 41
# First Name: Juan
# Last Name: Harris
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: fryrenee@example.net
# Address: "497 Alexander Camp
# SSN: 393607883
# Is Active: Y
# Qualifications: N/A
# Department ID: 1
# Department Head: John Smith
# Department Name: Cardiology_1
# Department Employee Count: 2
# ========================================
# id_employee: 42
# First Name: Donna
# Last Name: Adams
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: christopher30@example.net
# Address: Daltonhaven, MN 11752"
# SSN: 246634358
# Is Active: Y
# Qualifications: N/A
# Department ID: 2
# Department Head: Michael Williams
# Department Name: Emergency_2
# Department Employee Count: 3
# ========================================
# id_employee: 43
# First Name: Emily
# Last Name: Ryan
# Job: Technician
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: mccormickbriana@example.net
# Address: "81336 Jacobson Cove Apt. 662
# SSN: 838811834
# Is Active: Y
# Qualifications: N/A
# Department ID: 3
# Department Head: Emily Johnson
# Department Name: Diagnostic_3
# Department Employee Count: 3
# ========================================
# id_employee: 44
# First Name: Jacob
# Last Name: Henry
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: vanessabailey@example.com
# Address: Kimberlymouth, OK 53606"
# SSN: 471655403
# Is Active: Y
# Qualifications: N/A
# Department ID: 4
# Department Head: Jessica Brown
# Department Name: Cardiology_4
# Department Employee Count: 2
# ========================================
# id_employee: 45
# First Name: Joseph
# Last Name: Jones
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: cshepard@example.org
# Address: "99962 Woods Path Apt. 757
# SSN: 566403689
# Is Active: Y
# Qualifications: N/A
# Department ID: 5
# Department Head: Christopher Lee
# Department Name: Emergency_1
# Department Employee Count: 2
# ========================================
# id_employee: 46
# First Name: Allison
# Last Name: Miller
# Job: Technician
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: zrichardson@example.org
# Address: Zacharyshire, MN 46324"
# SSN: 129657421
# Is Active: Y
# Qualifications: N/A
# Department ID: 6
# Department Head: Matthew Martinez
# Department Name: Diagnostic_1
# Department Employee Count: 1
# ========================================
# id_employee: 47
# First Name: Jason
# Last Name: Costa
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: edwardmorrow@example.com
# Address: "5589 Lance Corners
# SSN: 794001594
# Is Active: Y
# Qualifications: N/A
# Department ID: 7
# Department Head: Sophia Hernandez
# Department Name: Cardiology_3
# Department Employee Count: 3
# ========================================
# id_employee: 48
# First Name: Jennifer
# Last Name: Haynes
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: joshua90@example.net
# Address: Michaelburgh, OH 60130"
# SSN: 964443879
# Is Active: Y
# Qualifications: N/A
# Department ID: 8
# Department Head: Ethan Lopez
# Department Name: Cardiology_2
# Department Employee Count: 3
# ========================================
# id_employee: 49
# First Name: Ashley
# Last Name: Stein
# Job: Technician
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: krystal59@example.org
# Address: "8049 Adrian Throughway
# SSN: 414092098
# Is Active: Y
# Qualifications: N/A
# Department ID: 9
# Department Head: Travis Smith
# Department Name: Diagnostic_2
# Department Employee Count: 3
# ========================================
# id_employee: 50
# First Name: Holly
# Last Name: Palmer
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: marygriffin@example.net
# Address: East Josephton, CO 34654"
# SSN: 726379798
# Is Active: Y
# Qualifications: N/A
# Department ID: 10
# Department Head: Amanda Taylor
# Department Name: Pediatrics
# Department Employee Count: 2
# ========================================
# id_employee: 51
# First Name: Martha
# Last Name: Smith
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: rebecca99@example.net
# Address: "Unit 3517 Box 7175
# SSN: 625642285
# Is Active: Y
# Qualifications: N/A
# Department ID: 11
# Department Head: Daniel Garcia
# Department Name: Orthopedics
# Department Employee Count: 2
# ========================================
# id_employee: 52
# First Name: Christian
# Last Name: Robertson
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: bushjoshua@example.net
# Address: DPO AE 73139"
# SSN: 891778968
# Is Active: Y
# Qualifications: N/A
# Department ID: 12
# Department Head: Olivia Rodriguez
# Department Name: Neurology
# Department Employee Count: 1
# ========================================
# id_employee: 53
# First Name: Lisa
# Last Name: Dudley
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: kperkins@example.net
# Address: "1786 Debbie Terrace
# SSN: 336695154
# Is Active: Y
# Qualifications: N/A
# Department ID: 13
# Department Head: Noah Martinez
# Department Name: Oncology
# Department Employee Count: 1
# ========================================
# id_employee: 54
# First Name: Jennifer
# Last Name: Meyers
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: johnsonluis@example.com
# Address: New Kathyfurt, CT 94630"
# SSN: 216467215
# Is Active: Y
# Qualifications: N/A
# Department ID: 14
# Department Head: Isabella Hernandez
# Department Name: Radiology
# Department Employee Count: 5
# ========================================
# id_employee: 55
# First Name: Mr.
# Last Name: Matthew
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: lblanchard@example.net
# Address: "7808 Melanie Rue
# SSN: 136100833
# Is Active: N
# Qualifications: N/A
# Department ID: 15
# Department Head: William Johnson
# Department Name: Surgery
# Department Employee Count: 4
# ========================================
# id_employee: 56
# First Name: Aaron
# Last Name: Turner
# Job: Doctor
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: rodriguezmonica@example.com
# Address: Shirleyhaven, RI 48773"
# SSN: 443298172
# Is Active: N
# Qualifications: MD
# Department ID: 16
# Department Head: Sophia Lopez
# Department Name: Ophthalmology
# Department Employee Count: 5
# ========================================
# id_employee: 57
# First Name: Ellen
# Last Name: Wright
# Job: Doctor
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: michaellee@example.net
# Address: "19041 Nicholson Field Apt. 592
# SSN: 311230784
# Is Active: N
# Qualifications: MD
# Department ID: 17
# Department Head: Ethan Brown
# Department Name: Gynecology
# Department Employee Count: 5
# ========================================
# id_employee: 58
# First Name: Jane
# Last Name: Stafford
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: michaelrowe@example.com
# Address: East Andreaborough, DE 01264"
# SSN: 974891597
# Is Active: Y
# Qualifications: N/A
# Department ID: 18
# Department Head: Olivia Wilson
# Department Name: Urology
# Department Employee Count: 4
# ========================================
# id_employee: 59
# First Name: Nichole
# Last Name: Mckinney
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: phillipswilliam@example.com
# Address: "4645 Campos View
# SSN: 868868976
# Is Active: Y
# Qualifications: N/A
# Department ID: 19
# Department Head: Alexander Lee
# Department Name: Dermatology
# Department Employee Count: 6
# ========================================
# id_employee: 60
# First Name: Patricia
# Last Name: Carrillo
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: nealbrandi@example.org
# Address: Port Kim, AR 99466"
# SSN: 810734855
# Is Active: Y
# Qualifications: N/A
# Department ID: 20
# Department Head: Mia Garcia
# Department Name: Hematology
# Department Employee Count: 4
# ========================================
# id_employee: 61
# First Name: Edward
# Last Name: Allen
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: xadams@example.com
# Address: "09780 Johnson Manor
# SSN: 479489642
# Is Active: Y
# Qualifications: N/A
# Department ID: 21
# Department Head: James Martinez
# Department Name: Endocrinology
# Department Employee Count: 4
# ========================================
# id_employee: 62
# First Name: Kendra
# Last Name: Russell
# Job: Doctor
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: gregoryjohnson@example.net
# Address: Port Samuelmouth, NY 96222"
# SSN: 935471039
# Is Active: Y
# Qualifications: MD
# Department ID: 22
# Department Head: Sophia Anderson
# Department Name: Pulmonology
# Department Employee Count: 4
# ========================================
# id_employee: 63
# First Name: Destiny
# Last Name: Nicholson
# Job: Doctor
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: dana26@example.org
# Address: "8796 Rodney Vista Apt. 090
# SSN: 434075072
# Is Active: Y
# Qualifications: PhD
# Department ID: 23
# Department Head: Oliver Wilson
# Department Name: Nephrology
# Department Employee Count: 4
# ========================================
# id_employee: 64
# First Name: Alexander
# Last Name: Matthews
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: jvelazquez@example.com
# Address: Stuartton, MA 32158"
# SSN: 573643588
# Is Active: Y
# Qualifications: N/A
# Department ID: 24
# Department Head: Ava Hernandez
# Department Name: Otolaryngology
# Department Employee Count: 5
# ========================================
# id_employee: 65
# First Name: Jeffrey
# Last Name: Vega
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: jayers@example.org
# Address: "3237 Scott Centers
# SSN: 785307933
# Is Active: Y
# Qualifications: N/A
# Department ID: 25
# Department Head: Lucas Lopez
# Department Name: Rheumatology
# Department Employee Count: 5
# ========================================
# id_employee: 66
# First Name: Christina
# Last Name: Dalton
# Job: Doctor
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: josebriggs@example.net
# Address: East Nicholasland, IN 92402"
# SSN: 811295269
# Is Active: Y
# Qualifications: MD
# Department ID: 26
# Department Head: Emma Brown
# Department Name: Dentistry
# Department Employee Count: 10
# ========================================
# id_employee: 67
# First Name: Lauren
# Last Name: Campbell
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: 2018-10-02T00:00:00.000000000
# Email: rebeccayoung@example.net
# Address: "817 Julie Alley
# SSN: 159971018
# Is Active: N
# Qualifications: N/A
# Department ID: 27
# Department Head: Daniel Lee
# Department Name: Psychiatry
# Department Employee Count: 4
# ========================================
# id_employee: 68
# First Name: David
# Last Name: Mason
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: 2018-10-02T00:00:00.000000000
# Email: coltonlam@example.org
# Address: Kimberlyland, CO 43722"
# SSN: 714135708
# Is Active: N
# Qualifications: N/A
# Department ID: 1
# Department Head: John Smith
# Department Name: Cardiology_1
# Department Employee Count: 2
# ========================================
# id_employee: 69
# First Name: Maria
# Last Name: Gentry
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: 2018-10-02T00:00:00.000000000
# Email: gallegoskathleen@example.net
# Address: "888 Castro Field
# SSN: 111377409
# Is Active: N
# Qualifications: N/A
# Department ID: 2
# Department Head: Michael Williams
# Department Name: Emergency_2
# Department Employee Count: 3
# ========================================
# id_employee: 70
# First Name: Deborah
# Last Name: Collins
# Job: Technician
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: 2018-10-02T00:00:00.000000000
# Email: julie57@example.org
# Address: Freemanshire, FM 38384"
# SSN: 187814750
# Is Active: N
# Qualifications: N/A
# Department ID: 3
# Department Head: Emily Johnson
# Department Name: Diagnostic_3
# Department Employee Count: 3
# ========================================
# id_employee: 71
# First Name: Michael
# Last Name: Peterson
# Job: Doctor
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: 2018-10-02T00:00:00.000000000
# Email: cmiller@example.net
# Address: "498 Thomas Glen Apt. 314
# SSN: 488436028
# Is Active: N
# Qualifications: PhD
# Department ID: 4
# Department Head: Jessica Brown
# Department Name: Cardiology_4
# Department Employee Count: 2
# ========================================
# id_employee: 72
# First Name: William
# Last Name: Caldwell
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: 2018-10-02T00:00:00.000000000
# Email: christianmorgan@example.com
# Address: North Bianca, MS 81219"
# SSN: 847172402
# Is Active: N
# Qualifications: N/A
# Department ID: 5
# Department Head: Christopher Lee
# Department Name: Emergency_1
# Department Employee Count: 2
# ========================================
# id_employee: 73
# First Name: Linda
# Last Name: White
# Job: Technician
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: 2018-10-02T00:00:00.000000000
# Email: janicedunn@example.net
# Address: "2256 Robert Trail Suite 219
# SSN: 132945328
# Is Active: N
# Qualifications: N/A
# Department ID: 6
# Department Head: Matthew Martinez
# Department Name: Diagnostic_1
# Department Employee Count: 1
# ========================================
# id_employee: 74
# First Name: Michelle
# Last Name: Miller
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: 2018-10-02T00:00:00.000000000
# Email: sarahpowers@example.net
# Address: West Andrew, AR 42462"
# SSN: 349210973
# Is Active: N
# Qualifications: N/A
# Department ID: 7
# Department Head: Sophia Hernandez
# Department Name: Cardiology_3
# Department Employee Count: 3
# ========================================
# id_employee: 75
# First Name: Sherri
# Last Name: Owens
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: austin03@example.net
# Address: "2933 Jennifer Rapids
# SSN: 559964649
# Is Active: N
# Qualifications: N/A
# Department ID: 8
# Department Head: Ethan Lopez
# Department Name: Cardiology_2
# Department Employee Count: 3
# ========================================
# id_employee: 76
# First Name: Robert
# Last Name: Day
# Job: Technician
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: perkinsmaria@example.org
# Address: Aprilmouth, OH 09009"
# SSN: 429282057
# Is Active: Y
# Qualifications: N/A
# Department ID: 9
# Department Head: Travis Smith
# Department Name: Diagnostic_2
# Department Employee Count: 3
# ========================================
# id_employee: 77
# First Name: Andrea
# Last Name: Levine
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: ianbrown@example.org
# Address: "950 Cynthia Causeway
# SSN: 737429945
# Is Active: Y
# Qualifications: N/A
# Department ID: 10
# Department Head: Amanda Taylor
# Department Name: Pediatrics
# Department Employee Count: 2
# ========================================
# id_employee: 78
# First Name: James
# Last Name: Harris
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: ofrazier@example.org
# Address: Willistown, IA 71156"
# SSN: 777328798
# Is Active: Y
# Qualifications: N/A
# Department ID: 11
# Department Head: Daniel Garcia
# Department Name: Orthopedics
# Department Employee Count: 2
# ========================================
# id_employee: 79
# First Name: April
# Last Name: Gonzalez
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: ymiller@example.org
# Address: "PSC 4366, Box 9602
# SSN: 968052725
# Is Active: Y
# Qualifications: N/A
# Department ID: 12
# Department Head: Olivia Rodriguez
# Department Name: Neurology
# Department Employee Count: 1
# ========================================
# id_employee: 80
# First Name: Chase
# Last Name: West
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: hmassey@example.net
# Address: APO AA 58037"
# SSN: 833526949
# Is Active: Y
# Qualifications: N/A
# Department ID: 13
# Department Head: Noah Martinez
# Department Name: Oncology
# Department Employee Count: 1
# ========================================
# id_employee: 81
# First Name: Richard
# Last Name: Mendez
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: william33@example.net
# Address: "USNV Buck
# SSN: 881916036
# Is Active: Y
# Qualifications: N/A
# Department ID: 14
# Department Head: Isabella Hernandez
# Department Name: Radiology
# Department Employee Count: 5
# ========================================
# id_employee: 82
# First Name: Christopher
# Last Name: Martinez
# Job: Doctor
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: hberg@example.net
# Address: FPO AP 18208"
# SSN: 205720841
# Is Active: Y
# Qualifications: MD
# Department ID: 15
# Department Head: William Johnson
# Department Name: Surgery
# Department Employee Count: 4
# ========================================
# id_employee: 83
# First Name: Lee
# Last Name: Collins
# Job: Doctor
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: turnerjon@example.com
# Address: "4849 Loretta Villages
# SSN: 754480635
# Is Active: Y
# Qualifications: PhD
# Department ID: 16
# Department Head: Sophia Lopez
# Department Name: Ophthalmology
# Department Employee Count: 5
# ========================================
# id_employee: 84
# First Name: Jose
# Last Name: Romero
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: mwhite@example.net
# Address: East Brian, IN 88067"
# SSN: 968791178
# Is Active: Y
# Qualifications: N/A
# Department ID: 17
# Department Head: Ethan Brown
# Department Name: Gynecology
# Department Employee Count: 5
# ========================================
# id_employee: 85
# First Name: Ashley
# Last Name: Lucas
# Job: Doctor
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: sandovalapril@example.net
# Address: "Unit 0632 Box 4702
# SSN: 567117161
# Is Active: Y
# Qualifications: MD
# Department ID: 18
# Department Head: Olivia Wilson
# Department Name: Urology
# Department Employee Count: 4
# ========================================
# id_employee: 86
# First Name: Duane
# Last Name: Duncan
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: robin66@example.com
# Address: DPO AP 55248"
# SSN: 692796134
# Is Active: Y
# Qualifications: N/A
# Department ID: 19
# Department Head: Alexander Lee
# Department Name: Dermatology
# Department Employee Count: 6
# ========================================
# id_employee: 87
# First Name: Elizabeth
# Last Name: Scott
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: nicholasmeyers@example.org
# Address: "670 Paul Isle
# SSN: 698260708
# Is Active: Y
# Qualifications: N/A
# Department ID: 20
# Department Head: Mia Garcia
# Department Name: Hematology
# Department Employee Count: 4
# ========================================
# id_employee: 88
# First Name: Matthew
# Last Name: Luna
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: jeremyvasquez@example.com
# Address: Brianstad, MT 55405"
# SSN: 248680279
# Is Active: Y
# Qualifications: N/A
# Department ID: 21
# Department Head: James Martinez
# Department Name: Endocrinology
# Department Employee Count: 4
# ========================================
# id_employee: 89
# First Name: Rebecca
# Last Name: Reyes
# Job: Doctor
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: plewis@example.org
# Address: "00336 Savage Island
# SSN: 530811045
# Is Active: Y
# Qualifications: MD
# Department ID: 22
# Department Head: Sophia Anderson
# Department Name: Pulmonology
# Department Employee Count: 4
# ========================================
# id_employee: 90
# First Name: Sarah
# Last Name: Powell
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: calhounkelly@example.org
# Address: North Tanya, SC 55402"
# SSN: 380193465
# Is Active: Y
# Qualifications: N/A
# Department ID: 23
# Department Head: Oliver Wilson
# Department Name: Nephrology
# Department Employee Count: 4
# ========================================
# id_employee: 91
# First Name: Antonio
# Last Name: Mccall
# Job: Nurse
# Date Joining: 2014-10-02T00:00:00.000000000
# Date Separation: None
# Email: juliakelly@example.net
# Address: "6608 Lisa Tunnel
# SSN: 651169317
# Is Active: Y
# Qualifications: N/A
# Department ID: 24
# Department Head: Ava Hernandez
# Department Name: Otolaryngology
# Department Employee Count: 5
# ========================================
# id_employee: 92
# First Name: Sarah
# Last Name: Boyd
# Job: Doctor
# Date Joining: 2013-10-02T00:00:00.000000000
# Date Separation: None
# Email: dwatts@example.org
# Address: Matthewstad, MN 08177"
# SSN: 448343637
# Is Active: Y
# Qualifications: MD
# Department ID: 25
# Department Head: Lucas Lopez
# Department Name: Rheumatology
# Department Employee Count: 5
# ========================================
# id_employee: 93
# First Name: David
# Last Name: Hawkins
# Job: Nurse
# Date Joining: 2013-10-02T00:00:00.000000000
# Date Separation: None
# Email: michaelwarner@example.com
# Address: "993 Hunter Squares Apt. 437
# SSN: 370797821
# Is Active: Y
# Qualifications: N/A
# Department ID: 26
# Department Head: Emma Brown
# Department Name: Dentistry
# Department Employee Count: 10
# ========================================
# id_employee: 94
# First Name: David
# Last Name: Chapman
# Job: Nurse
# Date Joining: 2013-10-02T00:00:00.000000000
# Date Separation: None
# Email: garyriley@example.com
# Address: Port Sheilatown, CA 09096"
# SSN: 530216092
# Is Active: Y
# Qualifications: N/A
# Department ID: 27
# Department Head: Daniel Lee
# Department Name: Psychiatry
# Department Employee Count: 4
# ========================================
# id_employee: 95
# First Name: Kimberly
# Last Name: Hernandez
# Job: Nurse
# Date Joining: 2013-10-02T00:00:00.000000000
# Date Separation: None
# Email: kingjacob@example.com
# Address: "006 Daugherty Forest
# SSN: 562577558
# Is Active: Y
# Qualifications: N/A
# Department ID: 1
# Department Head: John Smith
# Department Name: Cardiology_1
# Department Employee Count: 2
# ========================================
# id_employee: 96
# First Name: Robert
# Last Name: Perez
# Job: Doctor
# Date Joining: 2013-10-02T00:00:00.000000000
# Date Separation: None
# Email: wagnersarah@example.net
# Address: South Danielmouth, TN 48233"
# SSN: 433087970
# Is Active: Y
# Qualifications: MD
# Department ID: 2
# Department Head: Michael Williams
# Department Name: Emergency_2
# Department Employee Count: 3
# ========================================
# id_employee: 97
# First Name: James
# Last Name: Palmer
# Job: Technician
# Date Joining: 2013-10-02T00:00:00.000000000
# Date Separation: None
# Email: kjackson@example.org
# Address: "92590 Erickson Ramp
# SSN: 570917164
# Is Active: Y
# Qualifications: N/A
# Department ID: 3
# Department Head: Emily Johnson
# Department Name: Diagnostic_3
# Department Employee Count: 3
# ========================================
# id_employee: 98
# First Name: Joshua
# Last Name: Clark
# Job: Nurse
# Date Joining: 2013-10-02T00:00:00.000000000
# Date Separation: None
# Email: samueljones@example.com
# Address: Frankbury, WA 21042"
# SSN: 914328842
# Is Active: Y
# Qualifications: N/A
# Department ID: 4
# Department Head: Jessica Brown
# Department Name: Cardiology_4
# Department Employee Count: 2
# ========================================
# id_employee: 99
# First Name: Brittany
# Last Name: Collins
# Job: Doctor
# Date Joining: 2013-10-02T00:00:00.000000000
# Date Separation: None
# Email: jennifer69@example.net
# Address: "6791 Riggs Avenue Suite 321
# SSN: 531214210
# Is Active: Y
# Qualifications: PhD
# Department ID: 5
# Department Head: Christopher Lee
# Department Name: Emergency_1
# Department Employee Count: 2
# ========================================
# id_employee: 100
# First Name: Angela
# Last Name: Park
# Job: Technician
# Date Joining: 2013-10-02T00:00:00.000000000
# Date Separation: None
# Email: williamsjames@example.net
# Address: West Michellefort, MO 61147"
# SSN: 705689027
# Is Active: Y
# Qualifications: N/A
# Department ID: 6
# Department Head: Matthew Martinez
# Department Name: Diagnostic_1
# Department Employee Count: 1
# ========================================
# Tempo de execução:
# - Neo4j: 0.0465981960
# Utilização de cpu:
# - Neo4j: -0.2
# Utilização de memória:
# - Neo4j: 811008

# %% [markdown]
# ## Query 2
# **Selecionar todos os patients onde o blood_type é 'A+'**

# %%
num = "2"
queries[num] = {
    "Query": "Selecionar todos os patients onde o blood_type é 'A+'",
    "neo4jTime": -1,
    "neo4jOutput": "",
    "neo4jCPU": -1,
    "neo4jMEM": -1
}

cpu_before, mem_before = monitor_usage()
start = time.time()
cypher_query = """
MATCH (p:Patient)
WHERE p.blood_type = 'A+'
RETURN p
"""
result = execute_query(cypher_query)
end = time.time()
cpu_after, mem_after = monitor_usage()

queries[num]["neo4jTime"] = f"{end - start:.10f}"
queries[num]["neo4jOutput"] = result
queries[num]["neo4jCPU"] = cpu_after - cpu_before
queries[num]["neo4jMEM"] = mem_after - mem_before

# Imprimir os resultados da query 2
for record in result:
        patient = record["p"]
        print(f"<id>: {patient['id']}")
        print(f"birthday: {patient['birthday']}")
        print(f"blood_type: {patient['blood_type']}")
        print(f"email: {patient['email']}")
        print(f"fname: {patient['fname']}")
        print(f"gender: {patient['gender']}")
        print(f"id: {patient['id']}")
        print(f"insurance_co_pay: {patient['insurance_co_pay']}")
        print(f"insurance_coverage: {patient['insurance_coverage']}")
        print(f"insurance_dental: {patient['insurance_dental']}")
        print(f"insurance_maternity: {patient['insurance_maternity']}")
        print(f"insurance_optical: {patient['insurance_optical']}")
        print(f"insurance_plan: {patient['insurance_plan']}")
        print(f"insurance_provider: {patient['insurance_provider']}")
        print(f"lname: {patient['lname']}")
        print(f"phone: {patient['phone']}")
        print(f"policy_number: {patient['policy_number']}")
        print("=" * 40)

print("Tempo de execução:")
print("- Neo4j:",queries[num]["neo4jTime"])
print("Utilização de cpu:")
print("- Neo4j:",queries[num]["neo4jCPU"])
print("Utilização de memória:")
print("- Neo4j:",queries[num]["neo4jMEM"])
# Out:
# <id>: 1
# birthday: 1985-07-15T00:00:00.000000000
# blood_type: A+
# email: john.doe@example.com
# fname: John
# gender: Male
# id: 1
# insurance_co_pay: 50.0
# insurance_coverage: Full Coverage
# insurance_dental: N
# insurance_maternity: Y
# insurance_optical: Y
# insurance_plan: Standard Plan
# insurance_provider: ABC Insurance
# lname: Doe
# phone: 123-456-7890
# policy_number: POL001
# ========================================
# <id>: 10
# birthday: 1992-01-05T00:00:00.000000000
# blood_type: A+
# email: emma.perez@example.com
# fname: Emma
# gender: Female
# id: 10
# insurance_co_pay: 15.0
# insurance_coverage: Limited Coverage
# insurance_dental: N
# insurance_maternity: N
# insurance_optical: N
# insurance_plan: Student Plan
# insurance_provider: YZA Insurance
# lname: Perez
# phone: 345-678-9012
# policy_number: POL010
# ========================================
# <id>: 18
# birthday: 1988-11-25T00:00:00.000000000
# blood_type: A+
# email: sophia.gonzalez@example.com
# fname: Sophia
# gender: Female
# id: 18
# insurance_co_pay: 45.0
# insurance_coverage: Partial Coverage
# insurance_dental: Y
# insurance_maternity: Y
# insurance_optical: N
# insurance_plan: Family Plan
# insurance_provider: STU Insurance
# lname: Gonzalez
# phone: 666-777-8888
# policy_number: POL008
# ========================================
# <id>: 25
# birthday: 1990-12-02T00:00:00.000000000
# blood_type: A+
# email: william.nguyen@example.com
# fname: William
# gender: Male
# id: 25
# insurance_co_pay: 35.0
# insurance_coverage: Partial Coverage
# insurance_dental: N
# insurance_maternity: Y
# insurance_optical: Y
# insurance_plan: Silver Plan
# insurance_provider: JKL Insurance
# lname: Nguyen
# phone: 567-890-1234
# policy_number: POL005
# ========================================
# <id>: 32
# birthday: 1995-09-13T00:00:00.000000000
# blood_type: A+
# email: isabella.phan@example.com
# fname: Isabella
# gender: Female
# id: 32
# insurance_co_pay: 30.0
# insurance_coverage: Partial Coverage
# insurance_dental: Y
# insurance_maternity: N
# insurance_optical: Y
# insurance_plan: Premium Plan
# insurance_provider: XYZ Insurance
# lname: Phan
# phone: 234-567-8901
# policy_number: POL002
# ========================================
# <id>: 40
# birthday: 1988-08-25T00:00:00.000000000
# blood_type: A+
# email: alexander.ho@example.com
# fname: Alexander
# gender: Male
# id: 40
# insurance_co_pay: 30.0
# insurance_coverage: Partial Coverage
# insurance_dental: Y
# insurance_maternity: N
# insurance_optical: Y
# insurance_plan: Premium Plan
# insurance_provider: XYZ Insurance
# lname: Ho
# phone: 012-345-6789
# policy_number: POL002
# ========================================
# <id>: 46
# birthday: 1983-08-07T00:00:00.000000000
# blood_type: A+
# email: daniel.do@example.com
# fname: Daniel
# gender: Male
# id: 46
# insurance_co_pay: 25.0
# insurance_coverage: Limited Coverage
# insurance_dental: Y
# insurance_maternity: N
# insurance_optical: N
# insurance_plan: Bronze Plan
# insurance_provider: MNO Insurance
# lname: Do
# phone: 678-901-2345
# policy_number: POL006
# ========================================
# <id>: 54
# birthday: 1983-12-05T00:00:00.000000000
# blood_type: A+
# email: noah.vo@example.com
# fname: Noah
# gender: Male
# id: 54
# insurance_co_pay: 40.0
# insurance_coverage: Full Coverage
# insurance_dental: Y
# insurance_maternity: N
# insurance_optical: Y
# insurance_plan: Gold Plan
# insurance_provider: GHI Insurance
# lname: Vo
# phone: 450-987-6543
# policy_number: POL004
# ========================================
# <id>: 68
# birthday: 1988-12-25T00:00:00.000000000
# blood_type: A+
# email: alexander.dang@example.com
# fname: Alexander
# gender: Male
# id: 68
# insurance_co_pay: 45.0
# insurance_coverage: Partial Coverage
# insurance_dental: Y
# insurance_maternity: Y
# insurance_optical: N
# insurance_plan: Family Plan
# insurance_provider: STU Insurance
# lname: Dang
# phone: 876-543-2109
# policy_number: POL008
# ========================================
# <id>: 76
# birthday: 1994-07-15T00:00:00.000000000
# blood_type: A+
# email: william.bui@example.com
# fname: William
# gender: Male
# id: 76
# insurance_co_pay: 25.0
# insurance_coverage: Limited Coverage
# insurance_dental: Y
# insurance_maternity: N
# insurance_optical: N
# insurance_plan: Bronze Plan
# insurance_provider: MNO Insurance
# lname: Bui
# phone: 432-109-8765
# policy_number: POL006
# ========================================
# <id>: 87
# birthday: 1984-12-20T00:00:00.000000000
# blood_type: A+
# email: madison.nguyen@example.com
# fname: Madison
# gender: Female
# id: 87
# insurance_co_pay: 60.0
# insurance_coverage: Full Coverage
# insurance_dental: Y
# insurance_maternity: Y
# insurance_optical: Y
# insurance_plan: Platinum Plan
# insurance_provider: PQR Insurance
# lname: Nguyen
# phone: 321-098-7654
# policy_number: POL007
# ========================================
# Tempo de execução:
# - Neo4j: 0.0077350140
# Utilização de cpu:
# - Neo4j: -0.3
# Utilização de memória:
# - Neo4j: 16384

# %% [markdown]
# ## Query 3
# **Buscar as informações do paciente de id 10.**

# %%
num = "3"
queries[num] = {
    "Query": "Buscar as informações do paciente de id 10.",
    "neo4jTime": -1,
    "neo4jOutput": "",
    "neo4jCPU": -1,
    "neo4jMEM": -1
}

cpu_before, mem_before = monitor_usage()
start = time.time()
cypher_query = """
MATCH (p:Patient)
WHERE p.id = 10
RETURN p
"""
result = execute_query(cypher_query)
end = time.time()
cpu_after, mem_after = monitor_usage()

queries[num]["neo4jTime"] = f"{end - start:.10f}"
queries[num]["neo4jOutput"] = result
queries[num]["neo4jCPU"] = cpu_after - cpu_before
queries[num]["neo4jMEM"] = mem_after - mem_before

# Imprimir os resultados da query 3
for record in result:
        patient = record["p"]
        print(f"<id>: {patient['id']}")
        print(f"birthday: {patient['birthday']}")
        print(f"blood_type: {patient['blood_type']}")
        print(f"email: {patient['email']}")
        print(f"fname: {patient['fname']}")
        print(f"gender: {patient['gender']}")
        print(f"id: {patient['id']}")
        print(f"insurance_co_pay: {patient['insurance_co_pay']}")
        print(f"insurance_coverage: {patient['insurance_coverage']}")
        print(f"insurance_dental: {patient['insurance_dental']}")
        print(f"insurance_maternity: {patient['insurance_maternity']}")
        print(f"insurance_optical: {patient['insurance_optical']}")
        print(f"insurance_plan: {patient['insurance_plan']}")
        print(f"insurance_provider: {patient['insurance_provider']}")
        print(f"lname: {patient['lname']}")
        print(f"phone: {patient['phone']}")
        print(f"policy_number: {patient['policy_number']}")
        print("=" * 40)

print("Tempo de execução:")
print("- Neo4j:",queries[num]["neo4jTime"])
print("Utilização de cpu:")
print("- Neo4j:",queries[num]["neo4jCPU"])
print("Utilização de memória:")
print("- Neo4j:",queries[num]["neo4jMEM"])
# Out:
# <id>: 10
# birthday: 1992-01-05T00:00:00.000000000
# blood_type: A+
# email: emma.perez@example.com
# fname: Emma
# gender: Female
# id: 10
# insurance_co_pay: 15.0
# insurance_coverage: Limited Coverage
# insurance_dental: N
# insurance_maternity: N
# insurance_optical: N
# insurance_plan: Student Plan
# insurance_provider: YZA Insurance
# lname: Perez
# phone: 345-678-9012
# policy_number: POL010
# ========================================
# Tempo de execução:
# - Neo4j: 0.0039160252
# Utilização de cpu:
# - Neo4j: -0.4
# Utilização de memória:
# - Neo4j: 4096

# %% [markdown]
# ## Query 4
# **Buscar as informações do doctor de id 24.**

# %%
num = "4"
queries[num] = {
    "Query": "Buscar as informações do doctor de id 24.",
    "neo4jTime": -1,
    "neo4jOutput": "",
    "neo4jCPU": -1,
    "neo4jMEM": -1
}

cpu_before, mem_before = monitor_usage()
start = time.time()
cypher_query = """
MATCH (d:Employee)
WHERE d.id_employee = 24 AND d.job = 'Doctor'
RETURN d
"""
result = execute_query(cypher_query)
end = time.time()
cpu_after, mem_after = monitor_usage()

queries[num]["neo4jTime"] = f"{end - start:.10f}"
queries[num]["neo4jOutput"] = result
queries[num]["neo4jCPU"] = cpu_after - cpu_before
queries[num]["neo4jMEM"] = mem_after - mem_before

# Imprimir os resultados da query 4
for record in result:
    doctor = record["d"]
    print(f"<id>: {doctor['id_employee']}")
    print(f"address: {doctor['address']}")
    print(f"data_joining: \"{doctor['data_joining']}\"")
    print(f"data_seperation: \"{doctor['data_seperation']}\"")
    print(f"department_emp_count: {doctor['department_emp_count']}")
    print(f"department_head: {doctor['department_head']}")
    print(f"department_id: {doctor['department_id']}")
    print(f"department_name: {doctor['department_name']}")
    print(f"email: {doctor['email']}")
    print(f"fname: {doctor['fname']}")
    print(f"id_employee: {doctor['id_employee']}")
    print(f"is_active_status: {doctor['is_active_status']}")
    print(f"job: {doctor['job']}")
    print(f"lname: {doctor['lname']}")
    print(f"qualifications: {doctor.get('qualifications', 'N/A')}")
    print(f"ssn: {doctor['ssn']}")
    print("=" * 40)

print("Tempo de execução:")
print("- Neo4j:",queries[num]["neo4jTime"])
print("Utilização de cpu:")
print("- Neo4j:",queries[num]["neo4jCPU"])
print("Utilização de memória:")
print("- Neo4j:",queries[num]["neo4jMEM"])
# Out:
# <id>: 24
# address: West Brianshire, NE 37671"
# data_joining: "2019-07-10T00:00:00.000000000"
# data_seperation: "2022-01-05T00:00:00.000000000"
# department_emp_count: 4
# department_head: Mia Garcia
# department_id: 20
# department_name: Hematology
# email: christineguzman@example.com
# fname: James
# id_employee: 24
# is_active_status: N
# job: Doctor
# lname: Carpenter
# qualifications: PhD
# ssn: 124291244
# ========================================
# Tempo de execução:
# - Neo4j: 0.0040950775
# Utilização de cpu:
# - Neo4j: -0.2
# Utilização de memória:
# - Neo4j: 0

# %% [markdown]
# ## Query 5
# **Calcula a soma cumulativa dos custos por paciente.**

# %%
num = "5"
queries[num] = {
    "Query": "Calcula a soma cumulativa dos custos por paciente.",
    "neo4jTime": -1,
    "neo4jOutput": "",
    "neo4jCPU": -1,
    "neo4jMEM": -1
}

cpu_before, mem_before = monitor_usage()
start = time.time()
cypher_query = """
MATCH (p:Patient)-[:HAS_EPISODE]->(:Episode)-[:HAS_BILL]->(b:Bill)
RETURN p.id AS patient_id, p.fname AS first_name, p.lname AS last_name, SUM(b.total) AS cumulative_cost
ORDER BY patient_id
"""
result = execute_query(cypher_query)
end = time.time()
cpu_after, mem_after = monitor_usage()


queries[num]["neo4jTime"] = f"{end - start:.10f}"
queries[num]["neo4jOutput"] = result
queries[num]["neo4jCPU"] = cpu_after - cpu_before
queries[num]["neo4jMEM"] = mem_after - mem_before

# Imprimir os resultados da query 5
for record in result:
    print(f"<elementId>: {record['patient_id']}:...")
    print(f"<id>: {record['patient_id']}")
    print(f"fname: {record['first_name']}")
    print(f"lname: {record['last_name']}")
    print(f"cumulative_cost: {record['cumulative_cost']}")
    print("=" * 40)

print("Tempo de execução:")
print("- Neo4j:",queries[num]["neo4jTime"])
print("Utilização de cpu:")
print("- Neo4j:",queries[num]["neo4jCPU"])
print("Utilização de memória:")
print("- Neo4j:",queries[num]["neo4jMEM"])
# Out:
# <elementId>: 2:...
# <id>: 2
# fname: Jane
# lname: Smith
# cumulative_cost: 10203.34
# ========================================
# <elementId>: 3:...
# <id>: 3
# fname: Michael
# lname: Johnson
# cumulative_cost: 3655.0
# ========================================
# <elementId>: 5:...
# <id>: 5
# fname: William
# lname: Martinez
# cumulative_cost: 7350.0
# ========================================
# <elementId>: 6:...
# <id>: 6
# fname: Sophia
# lname: Garcia
# cumulative_cost: 4570.0
# ========================================
# <elementId>: 9:...
# <id>: 9
# fname: Benjamin
# lname: Gonzalez
# cumulative_cost: 7845.0
# ========================================
# <elementId>: 11:...
# <id>: 11
# fname: Jacob
# lname: Rodriguez
# cumulative_cost: 6330.0
# ========================================
# <elementId>: 14:...
# <id>: 14
# fname: Mia
# lname: Gomez
# cumulative_cost: 1980.0
# ========================================
# <elementId>: 25:...
# <id>: 25
# fname: William
# lname: Nguyen
# cumulative_cost: 550.0
# ========================================
# <elementId>: 27:...
# <id>: 27
# fname: James
# lname: Kim
# cumulative_cost: 8370.0
# ========================================
# <elementId>: 28:...
# <id>: 28
# fname: Sophia
# lname: Le
# cumulative_cost: 13496.36
# ========================================
# <elementId>: 29:...
# <id>: 29
# fname: Logan
# lname: Do
# cumulative_cost: 10092.73
# ========================================
# <elementId>: 31:...
# <id>: 31
# fname: Ethan
# lname: Vo
# cumulative_cost: 340.0
# ========================================
# <elementId>: 33:...
# <id>: 33
# fname: Mason
# lname: Duong
# cumulative_cost: 11343.57
# ========================================
# <elementId>: 42:...
# <id>: 42
# fname: Jackson
# lname: Tran
# cumulative_cost: 7604.6
# ========================================
# <elementId>: 52:...
# <id>: 52
# fname: Ethan
# lname: Tran
# cumulative_cost: 1635.0
# ========================================
# <elementId>: 54:...
# <id>: 54
# fname: Noah
# lname: Vo
# cumulative_cost: 12020.0
# ========================================
# <elementId>: 55:...
# <id>: 55
# fname: Isabella
# lname: Huynh
# cumulative_cost: 14813.35
# ========================================
# <elementId>: 56:...
# <id>: 56
# fname: William
# lname: Do
# cumulative_cost: 1980.0
# ========================================
# <elementId>: 57:...
# <id>: 57
# fname: Sophia
# lname: Lam
# cumulative_cost: 11130.1
# ========================================
# <elementId>: 58:...
# <id>: 58
# fname: James
# lname: Mai
# cumulative_cost: 8655.88
# ========================================
# <elementId>: 60:...
# <id>: 60
# fname: Logan
# lname: Vo
# cumulative_cost: 610.0
# ========================================
# <elementId>: 62:...
# <id>: 62
# fname: Mason
# lname: Pham
# cumulative_cost: 6425.0
# ========================================
# <elementId>: 63:...
# <id>: 63
# fname: Harper
# lname: Ho
# cumulative_cost: 1720.0
# ========================================
# <elementId>: 64:...
# <id>: 64
# fname: Elijah
# lname: Truong
# cumulative_cost: 4700.0
# ========================================
# <elementId>: 65:...
# <id>: 65
# fname: Amelia
# lname: Le
# cumulative_cost: 2350.0
# ========================================
# <elementId>: 66:...
# <id>: 66
# fname: Benjamin
# lname: Ngo
# cumulative_cost: 3620.0
# ========================================
# <elementId>: 68:...
# <id>: 68
# fname: Alexander
# lname: Dang
# cumulative_cost: 11359.58
# ========================================
# <elementId>: 69:...
# <id>: 69
# fname: Abigail
# lname: Vuong
# cumulative_cost: 1425.0
# ========================================
# <elementId>: 70:...
# <id>: 70
# fname: Michael
# lname: Duong
# cumulative_cost: 9275.0
# ========================================
# <elementId>: 72:...
# <id>: 72
# fname: James
# lname: Vo
# cumulative_cost: 2300.42
# ========================================
# <elementId>: 73:...
# <id>: 73
# fname: Emma
# lname: Luu
# cumulative_cost: 5614.49
# ========================================
# <elementId>: 75:...
# <id>: 75
# fname: Avery
# lname: Hoang
# cumulative_cost: 14978.98
# ========================================
# <elementId>: 76:...
# <id>: 76
# fname: William
# lname: Bui
# cumulative_cost: 8665.0
# ========================================
# <elementId>: 78:...
# <id>: 78
# fname: Logan
# lname: Trinh
# cumulative_cost: 4200.0
# ========================================
# <elementId>: 82:...
# <id>: 82
# fname: Alexander
# lname: Ho
# cumulative_cost: 7422.57
# ========================================
# <elementId>: 84:...
# <id>: 84
# fname: Henry
# lname: Tran
# cumulative_cost: 690.0
# ========================================
# <elementId>: 85:...
# <id>: 85
# fname: Scarlett
# lname: Dang
# cumulative_cost: 1090.0
# ========================================
# <elementId>: 87:...
# <id>: 87
# fname: Madison
# lname: Nguyen
# cumulative_cost: 9129.27
# ========================================
# <elementId>: 89:...
# <id>: 89
# fname: Amelia
# lname: Tran
# cumulative_cost: 5886.11
# ========================================
# <elementId>: 90:...
# <id>: 90
# fname: Michael
# lname: Do
# cumulative_cost: 3250.0
# ========================================
# Tempo de execução:
# - Neo4j: 0.0100269318
# Utilização de cpu:
# - Neo4j: -0.2
# Utilização de memória:
# - Neo4j: 16384

# %% [markdown]
# ## Tempos de execução, Uso de CPU, Uso de memória

# %%
for key in queries:
    print(f"Query {key}: {queries[key]['Query']}")
    print(f"neo4jTime: {queries[key]['neo4jTime']}")
    print(f"neo4jCPU: {queries[key]['neo4jCPU']}")
    print(f"neo4jMEM: {queries[key]['neo4jMEM']}")       
    print()
# Out:
# Query 1: Selecionar todas as informações de todos os membros do Staff (doctors, nurses, technicians).
# neo4jTime: 0.0465981960
# neo4jCPU: -0.2
# neo4jMEM: 811008
#
# Query 2: Selecionar todos os patients onde o blood_type é 'A+'
# neo4jTime: 0.0077350140
# neo4jCPU: -0.3
# neo4jMEM: 16384
#
# Query 3: Buscar as informações do paciente de id 10.
# neo4jTime: 0.0039160252
# neo4jCPU: -0.4
# neo4jMEM: 4096
#
# Query 4: Buscar as informações do doctor de id 24.
# neo4jTime: 0.0040950775
# neo4jCPU: -0.2
# neo4jMEM: 0
#
# Query 5: Calcula a soma cumulativa dos custos por paciente.
# neo4jTime: 0.0100269318
# neo4jCPU: -0.2
# neo4jMEM: 16384
